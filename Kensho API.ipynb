# %% [markdown]
# "75cabbcbb13902d342ab56354f2f24830b4ca92b"
# https://www.kensho.com/external/v1/<endpoint>?<query>

# %% [markdown]
# # Using requests

# %%
import requests

r = requests.get('https://www.kensho.com/external/v1/')

# %%
r.status_code
# Out:
# 404

# %%
response = requests.get('https://www.kensho.com/external/v1/get_class_relationships?class_name=Equity', headers={'Authorization': 'Token 75cabbcbb13902d342ab56354f2f24830b4ca92b'})

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"data": [{"related_class": "Concept", "relationship_id": "EquityConcepts"}, {"related_class": "Equity", "relationship_id": "Peers"}, {"related_class": "Equity", "relationship_id": "EquitySuppliers"}, {"related_class": "Timeline", "relationship_id": "EquityTimelines"}, {"related_class": "Equity", "relationship_id": "EquityConsumers"}], "metadata": [{"key": "relationship_id", "name": "Relationship ID", "unit": "String"}, {"key": "related_class", "name": "Related Entity Class", "unit": "String"}]}'

# %%
response = requests.get('https://www.kensho.com/external/v1/translate_asset_id?id_type=TICKER&asset_id=AAPL', headers={'Authorization': 'Token 75cabbcbb13902d342ab56354f2f24830b4ca92b'})

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"data": [{"type": "KENSHO", "name": "f9d09c10-c6de-4e8f-9624-996774888bcc"}, {"type": "CUSIP", "name": "037833100"}, {"type": "TICKER", "name": "AAPL"}, {"type": "ISIN", "name": "US0378331005"}], "metadata": [{"key": "type", "name": "Identifier Type", "unit": "String"}, {"key": "name", "name": "Identifier", "unit": "String"}]}'

# %%
import json

# %%
check = json.loads(response.text)

# %%
check.keys()
# Out:
# dict_keys(['data', 'metadata'])

# %%
check['data'][0]['name']
# Out:
# 'f9d09c10-c6de-4e8f-9624-996774888bcc'

# %%
response = requests.get('https://www.kensho.com/external/v1/get_related_entities?entity_id={}&relationship=EquityTimelines'.format(check['data'][0]['name']), headers={'Authorization': 'Token 75cabbcbb13902d342ab56354f2f24830b4ca92b'})

# %%
response.text
# Out:
# '{"data": [{"entity_id": "ec5a179d-ae08-4912-8bca-6a348baa2213", "related_entities": [{"entity_id": "f9d09c10-c6de-4e8f-9624-996774888bcc", "entity_name": "Apple Inc. (AAPL)", "entity_type": "Equity"}, {"entity_id": "e8e36842-d63f-4d89-8523-f005396e2842", "entity_name": "Earnings", "entity_type": "TimelineType"}], "entity_name": "Apple Inc. (AAPL) Earnings Releases", "entity_type": "Timeline", "timeline_type": "Earnings", "entity_aliases": []}, {"entity_id": "7244135a-f39a-4443-94ed-5508b580cf9d", "related_entities": [{"entity_id": "f9d09c10-c6de-4e8f-9624-996774888bcc", "entity_name": "Apple Inc. (AAPL)", "entity_type": "Equity"}, {"entity_id": "96ab5874-3751-4045-b6f0-3ed4cce23935", "entity_name": "Corporate Guidance - Lowered", "entity_type": "TimelineType"}], "entity_name": "Apple Inc. Corporate Guidance - Lowered", "entity_type": "Timeline", "timeline_type": "Corporate Guidance - Lowered", "entity_aliases": []}, {"entity_id": "e8479f2e-4cc4-43f7-8d9a-b3e8d056b4a0", "related_entities": [{"entity_id": "f9d09c10-c6de-4e8f-9624-996774888bcc", "entity_name": "Apple Inc. (AAPL)", "entity_type": "Equity"}, {"entity_id": "32c7a8b3-5ba2-4054-9737-b648db6b4864", "entity_name": "Corporate Guidance - Raised", "entity_type": "TimelineType"}], "entity_name": "Apple Inc. Corporate Guidance - Raised", "entity_type": "Timeline", "timeline_type": "Corporate Guidance - Raised", "entity_aliases": []}, {"entity_id": "96b9e238-45f1-4949-855e-04312153f551", "related_entities": [{"entity_id": "f9d09c10-c6de-4e8f-9624-996774888bcc", "entity_name": "Apple Inc. (AAPL)", "entity_type": "Equity"}, {"entity_id": "4c1d559f-6b9c-4dff-b050-d2676c8160d5", "entity_name": "Corporate Guidance - New/Confirmed", "entity_type": "TimelineType"}], "entity_name": "Apple Inc. Corporate Guidance - New/Confirmed", "entity_type": "Timeline", "timeline_type": "Corporate Guidance - New/Confirmed", "entity_aliases": []}, {"entity_id": "b7f2edfa-4820-48e7-a96d-a11661e86a76", "related_entities": [{"entity_id": "f9d09c10-c6de-4e8f-9624-996774888bcc", "entity_name": "Apple Inc. (AAPL)", "entity_type": "Equity"}, {"entity_id": "d60cbde2-4241-45aa-ae43-7d2a466362f9", "entity_name": "Regulatory Agency Inquiries", "entity_type": "TimelineType"}], "entity_name": "Apple Inc. Regulatory Agency Inquiries", "entity_type": "Timeline", "timeline_type": "Regulatory Agency Inquiries", "entity_aliases": []}, {"entity_id": "c4df90c0-8a81-4fa5-9e1c-049c7d5989cd", "related_entities": [{"entity_id": "f9d09c10-c6de-4e8f-9624-996774888bcc", "entity_name": "Apple Inc. (AAPL)", "entity_type": "Equity"}, {"entity_id": "45d7a5d8-cd0d-44ea-916c-7fcd1f54e3b0", "entity_name": "Delayed Earnings Announcements", "entity_type": "TimelineType"}], "entity_name": "Apple Inc. Delayed Earnings Announcements", "entity_type": "Timeline", "timeline_type": "Delayed Earnings Announcements", "entity_aliases": []}, {"entity_id": "47d58960-8c89-451d-a16f-cf1b1c914523", "related_entities": [{"entity_id": "f9d09c10-c6de-4e8f-9624-996774888bcc", "entity_name": "Apple Inc. (AAPL)", "entity_type": "Equity"}, {"entity_id": "9d14a825-6dce-468f-9e91-3edc69747bed", "entity_name": "Dividend Affirmations", "entity_type": "TimelineType"}], "entity_name": "Apple Inc. Dividend Affirmations", "entity_type": "Timeline", "timeline_type": "Dividend Affirmations", "entity_aliases": []}, {"entity_id": "16772c7e-bf18-4b8d-ad47-31cde847a17d", "related_entities": [{"entity_id": "f9d09c10-c6de-4e8f-9624-996774888bcc", "entity_name": "Apple Inc. (AAPL)", "entity_type": "Equity"}, {"entity_id": "cfd874a8-74d1-4862-9c21-696a6764d030", "entity_name": "Dividend Increases", "entity_type": "TimelineType"}], "entity_name": "Apple Inc. Dividend Increases", "entity_type": "Timeline", "timeline_type": "Dividend Increases", "entity_aliases": []}, {"entity_id": "1faae521-3ecc-4f83-bbab-294b56b8c075", "related_entities": [{"entity_id": "3aab1ede-92b6-47f1-8deb-68acb1495884", "entity_name": "Annual General Meeting", "entity_type": "TimelineType"}, {"entity ...

# %%
check = json.loads(response.text)

# %%
check['data']
# Out:
# [{'entity_id': 'ec5a179d-ae08-4912-8bca-6a348baa2213',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'e8e36842-d63f-4d89-8523-f005396e2842',
#     'entity_name': 'Earnings',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. (AAPL) Earnings Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Earnings',
#   'entity_aliases': []},
#  {'entity_id': '7244135a-f39a-4443-94ed-5508b580cf9d',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '96ab5874-3751-4045-b6f0-3ed4cce23935',
#     'entity_name': 'Corporate Guidance - Lowered',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Corporate Guidance - Lowered',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Corporate Guidance - Lowered',
#   'entity_aliases': []},
#  {'entity_id': 'e8479f2e-4cc4-43f7-8d9a-b3e8d056b4a0',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '32c7a8b3-5ba2-4054-9737-b648db6b4864',
#     'entity_name': 'Corporate Guidance - Raised',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Corporate Guidance - Raised',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Corporate Guidance - Raised',
#   'entity_aliases': []},
#  {'entity_id': '96b9e238-45f1-4949-855e-04312153f551',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '4c1d559f-6b9c-4dff-b050-d2676c8160d5',
#     'entity_name': 'Corporate Guidance - New/Confirmed',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Corporate Guidance - New/Confirmed',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Corporate Guidance - New/Confirmed',
#   'entity_aliases': []},
#  {'entity_id': 'b7f2edfa-4820-48e7-a96d-a11661e86a76',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'd60cbde2-4241-45aa-ae43-7d2a466362f9',
#     'entity_name': 'Regulatory Agency Inquiries',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Regulatory Agency Inquiries',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Regulatory Agency Inquiries',
#   'entity_aliases': []},
#  {'entity_id': 'c4df90c0-8a81-4fa5-9e1c-049c7d5989cd',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '45d7a5d8-cd0d-44ea-916c-7fcd1f54e3b0',
#     'entity_name': 'Delayed Earnings Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Delayed Earnings Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Delayed Earnings Announcements',
#   'entity_aliases': []},
#  {'entity_id': '47d58960-8c89-451d-a16f-cf1b1c914523',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '9d14a825-6dce-468f-9e91-3edc69747bed',
#     'entity_name': 'Dividend Affirmations',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Dividend Affirmations',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Dividend Affirmations',
#   'entity_aliases': []},
#  {'entity_id': '16772c7e-bf18-4b8d-ad47-31cde847a17d',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'cfd874a8-74d1-4862-9c21-696a6764d030',
#     'entity_name': 'Dividend Increases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Dividend Increases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Dividend Increases',
#   'entity_aliases': []},
#  {'entity_id': '1faae521-3ecc-4f83-bbab-294b56b8c075',
#   'related_entities': [{'entity_id': '3aab1ede-92b6-47f1-8deb-68acb1495884',
#     'entity_name': 'Annual General Meeting',
#     'entity_type': 'TimelineType'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'Apple Inc. Annual General Meeting',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Annual General Meeting',
#   'entity_aliases': []},
#  {'entity_id': '344e59f3-36a5-49d6-9c16-c04ac94b3376',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f6d7f337-d991-49a0-af12-3e687b93ee51',
#     'entity_name': 'Discontinued Operations/Downsizings',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Discontinued Operations/Downsizings',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Discontinued Operations/Downsizings',
#   'entity_aliases': []},
#  {'entity_id': '063b5e60-ac28-46df-a69c-84333eae7438',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '36b9825e-983b-4a57-b9e5-02c8659b4d8d',
#     'entity_name': 'Delayed SEC Filings',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Delayed SEC Filings',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Delayed SEC Filings',
#   'entity_aliases': []},
#  {'entity_id': 'c745c041-b5df-4f16-b7a8-c3944990a09f',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '8e34b644-4190-4ad9-a748-8524fabd8de1',
#     'entity_name': 'Dividend Initiation',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Dividend Initiation',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Dividend Initiation',
#   'entity_aliases': []},
#  {'entity_id': 'db0c4d86-92ba-4bd2-8420-fcffa57ec503',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '465de126-df9a-4c18-a4e6-2ffcbddd99ae',
#     'entity_name': 'Buyback - Change in Plan Terms',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Buyback - Change in Plan Terms',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Buyback - Change in Plan Terms',
#   'entity_aliases': []},
#  {'entity_id': 'eb12cd47-1425-4358-8005-65e269d9c381',
#   'related_entities': [{'entity_id': '25014370-ce33-4e5c-8bde-14facbf65d32',
#     'entity_name': 'Buyback Tranche Update',
#     'entity_type': 'TimelineType'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'Apple Inc. Buyback Tranche Update',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Buyback Tranche Update',
#   'entity_aliases': []},
#  {'entity_id': 'c1829aba-9cd9-40e3-8ff6-6b2ccfa0a897',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fe570c2e-9c18-4946-bdd2-055b86c706fb',
#     'entity_name': 'Auditor Changes',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Auditor Changes',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Auditor Changes',
#   'entity_aliases': []},
#  {'entity_id': '9207db91-6aa7-4a77-99b3-0df81b020650',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'aa497aa3-0a61-4ef3-8617-ad2adf3c793b',
#     'entity_name': 'Name Changes',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Name Changes',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Name Changes',
#   'entity_aliases': []},
#  {'entity_id': '52813076-9932-48bb-8bf4-559558a8407f',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '01c26682-8ad3-4b82-9e9f-1003af896ad3',
#     'entity_name': 'Buyback Transaction Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Buyback Transaction Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Buyback Transaction Announcements',
#   'entity_aliases': []},
#  {'entity_id': '0412b91c-cb81-48a6-8f07-b58f5f41ae83',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '48237fa3-836c-4254-802f-113ade5b43f2',
#     'entity_name': 'Capital Raises',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Fixed Income Issuance Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Capital Raises',
#   'entity_aliases': []},
#  {'entity_id': '1dcaa221-1a3e-4808-9453-864af638ad43',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Key Personnel Role Start Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': '654753d1-e53e-43a5-acb7-6725f87912fc',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Key Personnel Role End Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': 'c989a05f-0585-4a6d-8f94-a67d9d9a994e',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Chief Operating Officer Start Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': '3489b1c7-70ec-446a-a568-9af68e8c4444',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Board Member Start Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': 'd407b8ec-e192-45ca-96ff-babb8c7e10bf',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Chief Operating Officer End Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': '6381301c-e36b-4911-9161-2756f45d3006',
#   'related_entities': [{'entity_id': '6205dfab-9d20-4933-b7ed-78b632bf1b64',
#     'entity_name': 'M&A',
#     'entity_type': 'TimelineType'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'Mergers and Acquisitions announcements by Apple Inc.',
#   'entity_type': 'Timeline',
#   'timeline_type': 'M&A',
#   'entity_aliases': []},
#  {'entity_id': '3e602bda-08f8-4a3f-8f8a-ac8c42ed5a26',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '650505b8-ead1-45ee-93ba-7369a49219c9',
#     'entity_name': 'Communications',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. CEO Speeches',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Communications',
#   'entity_aliases': []},
#  {'entity_id': '0330d0a6-8e39-4bc0-a962-824b75757a3a',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '650505b8-ead1-45ee-93ba-7369a49219c9',
#     'entity_name': 'Communications',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Board Member Speeches',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Communications',
#   'entity_aliases': []},
#  {'entity_id': '65467c7d-f78f-41f5-b779-fa0ecbddc941',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa491823-346f-4e45-b9b6-9752d242bff1',
#     'entity_name': 'Company Conference Presentations',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Company Conference Presentations',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Company Conference Presentations',
#   'entity_aliases': []},
#  {'entity_id': 'fc0551b2-9b3d-43a6-af5f-141a1f647a6a',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '650505b8-ead1-45ee-93ba-7369a49219c9',
#     'entity_name': 'Communications',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Chair Speeches',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Communications',
#   'entity_aliases': []},
#  {'entity_id': '51128f17-6d45-4187-b892-e4d9a91e38c8',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. CEO Start Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': 'b7a72d5c-31a5-4820-bf46-00ba586aa6e3',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Chief Technology Officer Start Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': '28147d2c-6ea6-41c0-b4d4-6c410ae86315',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Chair Start Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': '98ecc95d-3792-4b84-bdbc-341656bc1a35',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. CEO End Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': 'e64c6187-af8c-4a7d-9367-47b8373b905d',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Chief Technology Officer End Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': 'f31189df-c293-4696-92fd-a39860aa0f45',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Board Member End Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': '34037d65-96cb-49a5-a6b2-d41fdca36dad',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea',
#     'entity_name': 'Personnel',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Inc. Chair End Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Personnel',
#   'entity_aliases': []},
#  {'entity_id': '6726e83c-822f-4878-8358-4b476d993b5b',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'Fixed Income Issuances Closings for Apple',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Fixed Income Issuance Closings by Company',
#   'entity_aliases': []},
#  {'entity_id': '7b6164fe-b9d8-46ac-9960-433e8ed4c04d',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple iPhone Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': 'ceac9f82-b32a-4efc-85f3-6709b3f14292',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Global Product Releases and Events',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': 'cb83a2f2-17dc-4694-9669-1ef0bcf880ea',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '48237fa3-836c-4254-802f-113ade5b43f2',
#     'entity_name': 'Capital Raises',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Debt Raises',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Capital Raises',
#   'entity_aliases': []},
#  {'entity_id': '63b2bfed-fa63-4f54-af35-1af174721d43',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple iOS Operating System Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': 'afe37000-053b-4bad-9e82-6d2a7ca07ca3',
#   'related_entities': [{'entity_id': '6a000ac2-e348-4542-a4d0-d534578f476a',
#     'entity_name': 'Industry Conferences',
#     'entity_type': 'TimelineType'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161',
#     'entity_name': 'Tablets',
#     'entity_type': 'Concept'}],
#   'entity_name': 'Apple Worldwide Developers Conference (WWDC) begins',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Industry Conferences',
#   'entity_aliases': []},
#  {'entity_id': '41e3c935-d2e3-4b33-84b1-3935aa635425',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Global Product & Services Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': '3b0febbb-c91d-4464-b7c7-3bd70411db10',
#   'related_entities': [{'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba',
#     'entity_name': 'NXP Semiconductors N.V. (NXPI)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple iMac Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': 'ae250a9a-3fd7-460a-9954-8bfb0bdd38e5',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple iPhone Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': '1fa5be9d-b949-4016-ae8a-4d664835c086',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Mac OS X Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': '3eadeab4-c7c0-4bb1-b299-5884bf4d79c9',
#   'related_entities': [{'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba',
#     'entity_name': 'NXP Semiconductors N.V. (NXPI)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Recall and Replacement Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': 'db42d512-f622-4529-a6f3-b9e4f8a9f5b0',
#   'related_entities': [{'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'},
#    {'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba',
#     'entity_name': 'NXP Semiconductors N.V. (NXPI)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': 'e58aa3a4-44d2-46f0-bc15-81c58cea9174',
#     'entity_name': 'BlackBerry Limited (BB)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'Apple iPhone New Generation Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': '0c7731e6-f7f5-4572-9914-154ca9cab44c',
#   'related_entities': [{'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161',
#     'entity_name': 'Tablets',
#     'entity_type': 'Concept'},
#    {'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba',
#     'entity_name': 'NXP Semiconductors N.V. (NXPI)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple iPad Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': 'bd1ba551-ff1b-4ca9-8565-a9e599366556',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '434af9b7-3d9b-4a7f-a695-4a71e3050196',
#     'entity_name': 'Investor Activism',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Carl Icahn Apple Investment',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Investor Activism',
#   'entity_aliases': []},
#  {'entity_id': '94ef4c8c-6890-440f-8c6b-6779e693b656',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple New Product Line Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': '25342dcc-e8ac-4694-8e25-8725a4cb001c',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '2b96628d-5113-4549-a19a-3ba15926a0ce',
#     'entity_name': 'Partnerships',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Corporate Partnership Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Partnerships',
#   'entity_aliases': []},
#  {'entity_id': '44a2dd7e-3439-4102-8885-a55c528581d7',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple iOS Operating System Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': '8e913f51-13cb-487f-b231-7d77c3078441',
#   'related_entities': [{'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba',
#     'entity_name': 'NXP Semiconductors N.V. (NXPI)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': 'e58aa3a4-44d2-46f0-bc15-81c58cea9174',
#     'entity_name': 'BlackBerry Limited (BB)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple iPhone New Generation Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': 'e245d755-4b4a-4dab-8ff3-7c48706b8d57',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple New Product Line Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': '37f41f98-2030-45fb-a5a8-e8692baab0c5',
#   'related_entities': [{'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'},
#    {'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161',
#     'entity_name': 'Tablets',
#     'entity_type': 'Concept'},
#    {'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba',
#     'entity_name': 'NXP Semiconductors N.V. (NXPI)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'Apple iPad Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': '71972f6c-b1bc-4082-85a0-27ed88c7a647',
#   'related_entities': [{'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba',
#     'entity_name': 'NXP Semiconductors N.V. (NXPI)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple iMac Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': '80609696-b8df-43ab-b5e9-30b1e5b6eb43',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '434af9b7-3d9b-4a7f-a695-4a71e3050196',
#     'entity_name': 'Investor Activism',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Carl Icahn Statements/Letters on Apple',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Investor Activism',
#   'entity_aliases': []},
#  {'entity_id': '6f88160f-ba7a-4ff1-b1fe-4c14a0c16722',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '43b091dd-04a9-4c7f-b5d9-217e10f6fb28',
#     'entity_name': 'Penalties',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Fines Paid by Apple',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Penalties',
#   'entity_aliases': []},
#  {'entity_id': '014015c0-fd1e-4f7a-9465-ae2e7fadb9b5',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Original Series Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': 'c8019ac9-8f7e-4e0c-905a-9f233be30e27',
#   'related_entities': [{'entity_id': 'f1cee052-cf52-4344-b42a-92ccb2764f97',
#     'entity_name': 'Expansions',
#     'entity_type': 'TimelineType'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '96d1bc76-938e-41a2-ac17-be05a71c98ae',
#     'entity_name': 'Digital Payments',
#     'entity_type': 'Concept'}],
#   'entity_name': 'Apple Pay New Country Launches',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Expansions',
#   'entity_aliases': []},
#  {'entity_id': '19850a72-08b2-48e0-bd27-2338850f27d0',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '96d1bc76-938e-41a2-ac17-be05a71c98ae',
#     'entity_name': 'Digital Payments',
#     'entity_type': 'Concept'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Pay New Country Launch Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': '0b50c4f6-9804-4e3a-aac1-7540a23daa62',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': 'fa81c667-c139-4938-9a82-d209d78b54b6',
#     'entity_name': 'Lawsuits',
#     'entity_type': 'TimelineType'},
#    {'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161',
#     'entity_name': 'Tablets',
#     'entity_type': 'Concept'}],
#   'entity_name': 'Milestones in the Apple-FBI Encryption Case',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Lawsuits',
#   'entity_aliases': []},
#  {'entity_id': 'cab67e85-9983-4e9a-bce7-00f587d866fa',
#   'related_entities': [{'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba',
#     'entity_name': 'NXP Semiconductors N.V. (NXPI)',
#     'entity_type': 'Equity'},
#    {'entity_id': '6a000ac2-e348-4542-a4d0-d534578f476a',
#     'entity_name': 'Industry Conferences',
#     'entity_type': 'TimelineType'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'Apple Media Events',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Industry Conferences',
#   'entity_aliases': []},
#  {'entity_id': 'a60792f8-a4d7-405e-909d-f7da5857f569',
#   'related_entities': [{'entity_id': '623b20a9-deeb-4daa-9da6-95e3927c9350',
#     'entity_name': 'Level 3 Parent, LLC (LVLT)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'New Apple Services Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': '1f73c96f-4861-49c7-a161-400c74979f6e',
#   'related_entities': [{'entity_id': '623b20a9-deeb-4daa-9da6-95e3927c9350',
#     'entity_name': 'Level 3 Parent, LLC (LVLT)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'New Apple Services Release Dates',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': 'ae923559-ad94-49e2-85d2-20043f20b481',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '650505b8-ead1-45ee-93ba-7369a49219c9',
#     'entity_name': 'Communications',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Open Letters',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Communications',
#   'entity_aliases': []},
#  {'entity_id': '47acbab2-3e98-47fc-9280-97025b1ce4e7',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple MacBook Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': 'a0debd16-7178-4925-ba7e-2b4b82eded76',
#   'related_entities': [{'entity_id': '6205dfab-9d20-4933-b7ed-78b632bf1b64',
#     'entity_name': 'M&A',
#     'entity_type': 'TimelineType'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'Confirmed Apple Investments over $1M',
#   'entity_type': 'Timeline',
#   'timeline_type': 'M&A',
#   'entity_aliases': []},
#  {'entity_id': '7f9261b6-a6d8-485f-80aa-1acb6153da0a',
#   'related_entities': [{'entity_id': '5e4ed7a7-1926-491c-85fb-b05c835dc493',
#     'entity_name': 'Samsung Electronics Co., Ltd. (A005930)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa81c667-c139-4938-9a82-d209d78b54b6',
#     'entity_name': 'Lawsuits',
#     'entity_type': 'TimelineType'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161',
#     'entity_name': 'Tablets',
#     'entity_type': 'Concept'}],
#   'entity_name': 'Developments in Apple-Samsung Legal Disputes (International)',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Lawsuits',
#   'entity_aliases': []},
#  {'entity_id': 'cb12405c-ef6d-4150-a69e-691132b1357f',
#   'related_entities': [{'entity_id': '7754b877-b037-423b-8ab5-d0aba6031a0b',
#     'entity_name': 'US Dollar (Next day)',
#     'entity_type': 'Currency'},
#    {'entity_id': 'fa81c667-c139-4938-9a82-d209d78b54b6',
#     'entity_name': 'Lawsuits',
#     'entity_type': 'TimelineType'},
#    {'entity_id': '229c72a7-d35a-4290-8853-f97248c55243',
#     'entity_name': 'United States of America',
#     'entity_type': 'Region'},
#    {'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161',
#     'entity_name': 'Tablets',
#     'entity_type': 'Concept'},
#    {'entity_id': '5568e897-3cbd-4cbd-b038-7a740d43f55f',
#     'entity_name': 'US Dollar',
#     'entity_type': 'Currency'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': '5e4ed7a7-1926-491c-85fb-b05c835dc493',
#     'entity_name': 'Samsung Electronics Co., Ltd. (A005930)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'Developments in Apple-Samsung Legal Disputes (U.S.)',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Lawsuits',
#   'entity_aliases': []},
#  {'entity_id': 'a62b9358-f49d-4c49-bacc-f99ca7f83879',
#   'related_entities': [{'entity_id': '03b45cc0-f14a-4898-968b-8b8f60a3d64c',
#     'entity_name': 'Yuan Renminbi',
#     'entity_type': 'Currency'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b1e2b7e1-910b-4d85-b36c-ec995e0d2fa6',
#     'entity_name': 'China',
#     'entity_type': 'Region'},
#    {'entity_id': '43b091dd-04a9-4c7f-b5d9-217e10f6fb28',
#     'entity_name': 'Penalties',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'China Bans Apple Products or Services',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Penalties',
#   'entity_aliases': []},
#  {'entity_id': '7bebfb14-f5e5-4398-91b4-d10ca316574e',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '4f17c86f-5269-46ba-8cd7-47e927fe254b',
#     'entity_name': 'Product Outages',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Widely Reported Apple Service and Product Outages',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Outages',
#   'entity_aliases': []},
#  {'entity_id': '4ed741de-4e6a-4bd6-90a1-085baa3c1168',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '1f0667ed-3009-463a-9301-bfe158f863a8',
#     'entity_name': 'Wearables',
#     'entity_type': 'Concept'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple WatchOS Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': '0536b6f8-314a-4693-9712-e8031b4fb2dc',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '1f0667ed-3009-463a-9301-bfe158f863a8',
#     'entity_name': 'Wearables',
#     'entity_type': 'Concept'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Watch New Generation Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': '7599621b-a8fb-4f4b-9544-a01ae8d4e8c4',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'},
#    {'entity_id': '1f0667ed-3009-463a-9301-bfe158f863a8',
#     'entity_name': 'Wearables',
#     'entity_type': 'Concept'}],
#   'entity_name': 'Apple Watch New Generation Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': '561c60a1-6341-4c4f-b1cf-370468d1f810',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple MacBook Pro Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': 'f8bcbd7f-7f13-43be-b5c5-07503b6446ea',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': '569deaef-33c9-426f-a7c4-b392e94e0b1f',
#     'entity_name': 'Product Developments',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple iPhone Production Cuts',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Developments',
#   'entity_aliases': []},
#  {'entity_id': '31261ad7-a6fb-4d2b-9100-0a9696a5b5af',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Special Edition Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': 'fcd98482-d1f4-457e-9b9a-e0cbe2ccba56',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple MacBook Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': 'da32d6b3-456b-4dc5-b220-44dc19a594b0',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': '89a11e7c-b7a7-4692-8efe-7d33584e7fcf',
#     'entity_name': 'Contracts',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple Supplier Cancellation Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Contracts',
#   'entity_aliases': []},
#  {'entity_id': 'a66a18ff-95e1-4382-96af-d109f49d0ed5',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'},
#    {'entity_id': '1f0667ed-3009-463a-9301-bfe158f863a8',
#     'entity_name': 'Wearables',
#     'entity_type': 'Concept'}],
#   'entity_name': 'Apple WatchOS Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': '44a638ec-d5dd-442c-a039-f4fdc4b504b8',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3',
#     'entity_name': 'Product Releases',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple MacBook Air Releases',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Releases',
#   'entity_aliases': []},
#  {'entity_id': '4d1db123-7a8c-4885-880b-ce1431482d62',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'e8f371b9-17a4-4c39-9d53-f79dce1ca63b',
#     'entity_name': 'Publicity',
#     'entity_type': 'TimelineType'}],
#   'entity_name': "Developments in Apple's Tax Avoidance Controversies",
#   'entity_type': 'Timeline',
#   'timeline_type': 'Publicity',
#   'entity_aliases': []},
#  {'entity_id': 'cb9df46d-379d-4991-99e4-b0b35a8d846b',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '569deaef-33c9-426f-a7c4-b392e94e0b1f',
#     'entity_name': 'Product Developments',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple App Store Prices Changes',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Developments',
#   'entity_aliases': []},
#  {'entity_id': 'fa83ab0c-29fa-40b4-9726-eebd2be60cdb',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431',
#     'entity_name': 'Smartphones',
#     'entity_type': 'Concept'},
#    {'entity_id': '62ad3190-eb46-4824-bbe0-5e1ca3657fea',
#     'entity_name': 'QUALCOMM Incorporated (QCOM)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fa81c667-c139-4938-9a82-d209d78b54b6',
#     'entity_name': 'Lawsuits',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Developments in Apple-Qualcomm Legal Disputes',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Lawsuits',
#   'entity_aliases': []},
#  {'entity_id': '221738ee-9e04-491c-9fd1-35da6e9ffe75',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Mac OS X Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': '8179c835-93fd-4a97-85b1-01a51d4d8f1b',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f',
#     'entity_name': 'Product Announcements',
#     'entity_type': 'TimelineType'}],
#   'entity_name': 'Apple TV New Generation Announcements',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Product Announcements',
#   'entity_aliases': []},
#  {'entity_id': '09db9a44-b332-48b5-99a8-e5510148d85c',
#   'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
# ...
#     'entity_name': 'Juniper Networks, Inc. (JNPR)',
#     'entity_type': 'Equity'},
#    {'entity_id': '551bdddf-6e3b-41ac-aab9-cd6cf0b5c4c0',
#     'entity_name': 'Thomson Reuters Corporation (TRI)',
#     'entity_type': 'Equity'},
#    {'entity_id': '7f4d2aeb-8f98-4aea-8799-0bb122ea4e7d',
#     'entity_name': 'NVIDIA Corporation (NVDA)',
#     'entity_type': 'Equity'},
#    {'entity_id': '8391133b-8a5a-4b19-8fc8-2455c8a2ad9f',
#     'entity_name': 'JPMorgan Chase & Co. (JPM)',
#     'entity_type': 'Equity'},
#    {'entity_id': '62ad3190-eb46-4824-bbe0-5e1ca3657fea',
#     'entity_name': 'QUALCOMM Incorporated (QCOM)',
#     'entity_type': 'Equity'},
#    {'entity_id': '3dda1d43-6cd0-4fd9-be50-cf6ec853d2ce',
#     'entity_name': 'Qurate Retail, Inc. (LVNT.B)',
#     'entity_type': 'Equity'},
#    {'entity_id': '0f154c5b-90a2-40fc-89a0-c9fce7d05676',
#     'entity_name': 'Verizon Communications Inc. (VZ)',
#     'entity_type': 'Equity'},
#    {'entity_id': '304f53f0-8dd2-44ef-a99c-c57b54845949',
#     'entity_name': 'American Express Company (AXP)',
#     'entity_type': 'Equity'},
#    {'entity_id': '7c322f4f-7e9d-4d8d-9738-e32ff50be702',
#     'entity_name': 'Lam Research Corporation (LRCX)',
#     'entity_type': 'Equity'},
#    {'entity_id': '06826ee5-f5e2-4342-9bee-1a546db3b03b',
#     'entity_name': 'Microsoft Corporation (MSFT)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ce421b86-1a0b-463c-8067-6e7e0ef6c5e6',
#     'entity_name': 'Fidelity National Information Services, Inc. (FIS)',
#     'entity_type': 'Equity'},
#    {'entity_id': '6b7f93a8-cb9b-4358-a2a8-a1152377f4fc',
#     'entity_name': 'Altaba Inc. (AABA)',
#     'entity_type': 'Equity'},
#    {'entity_id': '7e8cac76-7eb3-4d15-953a-44703385819b',
#     'entity_name': 'PayPal Holdings, Inc. (PYPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '7089cac3-4d7b-47d7-a211-4afe15b94622',
#     'entity_name': 'Nippon Telegraph and Telephone Corporation (9432)',
#     'entity_type': 'Equity'},
#    {'entity_id': '623b20a9-deeb-4daa-9da6-95e3927c9350',
#     'entity_name': 'Level 3 Parent, LLC (LVLT)',
#     'entity_type': 'Equity'},
#    {'entity_id': '0f99a5f1-c211-4b1b-9f5c-ed08e5b74c18',
#     'entity_name': 'First Solar, Inc. (FSLR)',
#     'entity_type': 'Equity'},
#    {'entity_id': '702350dc-6ef8-4310-a5ab-a7aa5e7af188',
#     'entity_name': 'Citrix Systems, Inc. (CTXS)',
#     'entity_type': 'Equity'},
#    {'entity_id': '6ce83421-1fff-4358-8ce9-ad24a7d4d2ad',
#     'entity_name': 'Microchip Technology Incorporated (MCHP)',
#     'entity_type': 'Equity'},
#    {'entity_id': '130b60d9-7078-4079-ba70-dc4b818aeaec',
#     'entity_name': 'Broadcom Inc. (AVGO)',
#     'entity_type': 'Equity'},
#    {'entity_id': '8e6ad15c-4c63-40b9-888e-5cb77e9d35ba',
#     'entity_name': 'Twitter, Inc. (TWTR)',
#     'entity_type': 'Equity'},
#    {'entity_id': '9d110065-1215-469b-81e0-1e626a74f5ad',
#     'entity_name': 'Intel Corporation (INTC)',
#     'entity_type': 'Equity'},
#    {'entity_id': '214032a1-c5d9-4976-8bcc-2518f577d55d',
#     'entity_name': 'KLA-Tencor Corporation (KLAC)',
#     'entity_type': 'Equity'},
#    {'entity_id': '3bf226be-0104-4c01-9310-f3877f46d475',
#     'entity_name': 'Viacom, Inc. (VIAB)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'JPMorgan Global Technology, Media and Telecom Conferences Start Date',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Industry Conferences',
#   'entity_aliases': []},
#  {'entity_id': '574e43f7-d88b-4e8e-8b0f-71faa4a67039',
#   'related_entities': [{'entity_id': '03e7519b-cd37-4b57-8aa4-1fb582f370d7',
#     'entity_name': 'STMicroelectronics N.V. (STM)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ee30f339-7240-4c7f-b08f-dc0d8d543cc6',
#     'entity_name': 'Canon Inc. (7751)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b947ea63-eac3-4375-abee-333b1db74b85',
#     'entity_name': 'Oracle Corporation (ORCL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'b2d8e6ee-8713-4956-bd7b-444197636641',
#     'entity_name': 'Cognizant Technology Solutions Corporation (CTSH)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'cfb73e32-4fa8-4701-898c-6c39279bbdb4',
#     'entity_name': 'Amazon.com, Inc. (AMZN)',
#     'entity_type': 'Equity'},
#    {'entity_id': '091a264f-dbf1-4090-9fd4-496f7c336f04',
#     'entity_name': 'Qurate Retail, Inc. (LVNTA)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'ecaf2b68-a90a-4a88-ae27-2a85572c3fce',
#     'entity_name': 'Finisar Corporation (FNSR)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'd3ab7464-6819-4b43-afbb-073c0f5a6c1c',
#     'entity_name': 'Panasonic Corporation (6752)',
#     'entity_type': 'Equity'},
#    {'entity_id': '8e971eb5-6854-4969-abe9-26d89a01cf35',
#     'entity_name': 'HP Inc. (HPQ)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fdd3dc99-a65c-4fe9-8cfe-0df9dd24138f',
#     'entity_name': 'Sprint Corporation (S)',
#     'entity_type': 'Equity'},
#    {'entity_id': '8a585ecf-fbe7-4e90-a7ce-6d2844ee91a5',
#     'entity_name': 'T-Mobile US, Inc. (TMUS)',
#     'entity_type': 'Equity'},
#    {'entity_id': '6522e9ca-4645-4ee3-9f01-8e41a54e66b8',
#     'entity_name': 'Comcast Corporation (CMCS.A)',
#     'entity_type': 'Equity'},
#    {'entity_id': '41d5fbe4-7e2a-4f5b-82f4-c81fe3de44a1',
#     'entity_name': 'Nexstar Media Group, Inc. (NXST)',
#     'entity_type': 'Equity'},
#    {'entity_id': '9d9b1c04-022e-47fe-af54-091908483897',
#     'entity_name': 'Adobe Systems Incorporated (ADBE)',
#     'entity_type': 'Equity'},
#    {'entity_id': '8145cd22-43cb-4911-8b91-d3fa8f69cc9d',
#     'entity_name': 'Netflix, Inc. (NFLX)',
#     'entity_type': 'Equity'},
#    {'entity_id': '6150860b-535d-41c3-bbf4-bacaae4c5403',
#     'entity_name': 'Xerox Corporation (XRX)',
#     'entity_type': 'Equity'},
#    {'entity_id': '37c53a09-309b-40bc-b165-90f0aac44366',
#     'entity_name': 'Alphabet Inc. (GOOG)',
#     'entity_type': 'Equity'},
#    {'entity_id': '6952e1b1-cb13-4465-9f54-56d6145d9068',
#     'entity_name': 'Micron Technology, Inc. (MU)',
#     'entity_type': 'Equity'},
#    {'entity_id': '42db86e9-808f-4ec6-a2ed-d5c9b8e4cdbc',
#     'entity_name': 'AT&T Inc. (T)',
#     'entity_type': 'Equity'},
#    {'entity_id': '941ef5a5-19cd-436d-a8df-18af60742539',
#     'entity_name': 'Skyworks Solutions, Inc. (SWKS)',
#     'entity_type': 'Equity'},
#    {'entity_id': '5569f0a7-3703-4506-8e13-48da4fb0eaa4',
#     'entity_name': 'VMware, Inc. (VMW)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'bff241df-9158-4a57-bcd3-3bae9b9680bb',
#     'entity_name': 'Texas Instruments Incorporated (TXN)',
#     'entity_type': 'Equity'},
#    {'entity_id': '0012e47e-cd4a-4630-83ab-7110123bbc07',
#     'entity_name': 'Canon Inc. (CAJ)',
#     'entity_type': 'Equity'},
#    {'entity_id': '5d65fe2b-85a4-450a-a042-ba37ecf04b2c',
#     'entity_name': 'Mercadolibre, Inc. (MELI)',
#     'entity_type': 'Equity'},
#    {'entity_id': '00575a39-118f-46ad-b498-1427b64baba0',
#     'entity_name': 'Morgan Stanley (MS)',
#     'entity_type': 'Equity'},
#    {'entity_id': '404ae198-2d24-41a7-80b5-ec9aed82ca6a',
#     'entity_name': 'Equinix, Inc. (REIT) (EQIX)',
#     'entity_type': 'Equity'},
#    {'entity_id': '0ebbdfd6-d8e0-4a55-b0fb-b66a1498832c',
#     'entity_name': 'Qorvo, Inc. (QRVO)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'c03414b5-bf25-4f64-b5c8-ae50fc5b9e14',
#     'entity_name': 'Alphabet Inc. (GOOG.L)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fe923b8e-7e31-4a47-8976-a5d8fff1867a',
#     'entity_name': 'Applied Materials, Inc. (AMAT)',
#     'entity_type': 'Equity'},
#    {'entity_id': '0f94e2ac-f556-4bcc-86b1-7182fec9a284',
#     'entity_name': 'Xilinx, Inc. (XLNX)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'db4dfc5e-0df9-4034-b261-78b1b8786f9c',
#     'entity_name': 'Accenture plc (ACN)',
#     'entity_type': 'Equity'},
#    {'entity_id': '6a000ac2-e348-4542-a4d0-d534578f476a',
#     'entity_name': 'Industry Conferences',
#     'entity_type': 'TimelineType'},
#    {'entity_id': 'fa4c20cc-88c8-4c84-8783-587d92e2640d',
#     'entity_name': 'Alibaba Group Holding Limited (BABA)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '8041834a-3a48-4d89-a36f-304f16bbf8a5',
#     'entity_name': 'The Interpublic Group of Companies, Inc. (IPG)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'd017caaf-3b4d-4920-9e1a-58a46d6ba20e',
#     'entity_name': 'F5 Networks, Inc. (FFIV)',
#     'entity_type': 'Equity'},
#    {'entity_id': '0321654a-3c5f-42e3-935c-b282ac22ffd3',
#     'entity_name': 'Sony Corporation (SNE)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'e84989bf-334a-4889-9ee7-f283ed54fd9a',
#     'entity_name': 'SAP SE (SAP)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba',
#     'entity_name': 'NXP Semiconductors N.V. (NXPI)',
#     'entity_type': 'Equity'},
#    {'entity_id': '0c03b3d1-acd8-4034-a6c6-e1232edae73d',
#     'entity_name': 'Linear Technology Corporation (LLTC)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'f4dd0fb5-dc72-421a-be23-84a22a06a478',
#     'entity_name': 'Sony Corporation (6758)',
#     'entity_type': 'Equity'},
#    {'entity_id': '06e0290b-ffdf-44a2-9a78-29052e07cb69',
#     'entity_name': 'STMicroelectronics N.V. (STM)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'a4af1f48-c6b6-470d-b7d7-61386a604765',
#     'entity_name': 'Maxim Integrated Products, Inc. (MXIM)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'edf557cc-da2c-4db7-8e15-7a60da428082',
#     'entity_name': 'Charter Communications, Inc. (CHTR)',
#     'entity_type': 'Equity'},
#    {'entity_id': '2fbf2728-1865-4cc8-a641-10772e99034d',
#     'entity_name': 'Seagate Technology plc (STX)',
#     'entity_type': 'Equity'},
#    {'entity_id': '9df60204-2c65-4d05-8d09-4b1edd614c27',
#     'entity_name': 'eBay Inc. (EBAY)',
#     'entity_type': 'Equity'},
#    {'entity_id': '39182bbd-5bf6-4bc2-82df-99b28521229a',
#     'entity_name': 'Analog Devices, Inc. (ADI)',
#     'entity_type': 'Equity'},
#    {'entity_id': '2fae8b76-1488-4543-a5ef-10db02bc2616',
#     'entity_name': 'DISH Network Corporation (DISH)',
#     'entity_type': 'Equity'},
#    {'entity_id': '3eb5c880-2423-4a17-bc38-b74d629bc599',
#     'entity_name': 'SAP SE (SAP)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'd3fbbaf0-395a-4fcc-8f49-887dd9a317bb',
#     'entity_name': 'Viacom, Inc. (VIA)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'd8ce5287-c2c4-4c5a-8ec7-334b8213de4b',
#     'entity_name': 'Facebook, Inc. (FB)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'e193a0df-6904-4ef0-8006-ea9fdbb34a97',
#     'entity_name': 'Juniper Networks, Inc. (JNPR)',
#     'entity_type': 'Equity'},
#    {'entity_id': '551bdddf-6e3b-41ac-aab9-cd6cf0b5c4c0',
#     'entity_name': 'Thomson Reuters Corporation (TRI)',
#     'entity_type': 'Equity'},
#    {'entity_id': '7f4d2aeb-8f98-4aea-8799-0bb122ea4e7d',
#     'entity_name': 'NVIDIA Corporation (NVDA)',
#     'entity_type': 'Equity'},
#    {'entity_id': '8e6ad15c-4c63-40b9-888e-5cb77e9d35ba',
#     'entity_name': 'Twitter, Inc. (TWTR)',
#     'entity_type': 'Equity'},
#    {'entity_id': '62ad3190-eb46-4824-bbe0-5e1ca3657fea',
#     'entity_name': 'QUALCOMM Incorporated (QCOM)',
#     'entity_type': 'Equity'},
#    {'entity_id': '3dda1d43-6cd0-4fd9-be50-cf6ec853d2ce',
#     'entity_name': 'Qurate Retail, Inc. (LVNT.B)',
#     'entity_type': 'Equity'},
#    {'entity_id': '0f154c5b-90a2-40fc-89a0-c9fce7d05676',
#     'entity_name': 'Verizon Communications Inc. (VZ)',
#     'entity_type': 'Equity'},
#    {'entity_id': '1b46389f-0c72-4f34-97f9-00abc32f9e83',
#     'entity_name': 'International Business Machines Corporation (IBM)',
#     'entity_type': 'Equity'},
#    {'entity_id': '7c322f4f-7e9d-4d8d-9738-e32ff50be702',
#     'entity_name': 'Lam Research Corporation (LRCX)',
#     'entity_type': 'Equity'},
#    {'entity_id': '06826ee5-f5e2-4342-9bee-1a546db3b03b',
#     'entity_name': 'Microsoft Corporation (MSFT)',
#     'entity_type': 'Equity'},
#    {'entity_id': '6b7f93a8-cb9b-4358-a2a8-a1152377f4fc',
#     'entity_name': 'Altaba Inc. (AABA)',
#     'entity_type': 'Equity'},
#    {'entity_id': '7e8cac76-7eb3-4d15-953a-44703385819b',
#     'entity_name': 'PayPal Holdings, Inc. (PYPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': '623b20a9-deeb-4daa-9da6-95e3927c9350',
#     'entity_name': 'Level 3 Parent, LLC (LVLT)',
#     'entity_type': 'Equity'},
#    {'entity_id': '0f99a5f1-c211-4b1b-9f5c-ed08e5b74c18',
#     'entity_name': 'First Solar, Inc. (FSLR)',
#     'entity_type': 'Equity'},
#    {'entity_id': '702350dc-6ef8-4310-a5ab-a7aa5e7af188',
#     'entity_name': 'Citrix Systems, Inc. (CTXS)',
#     'entity_type': 'Equity'},
#    {'entity_id': '6ce83421-1fff-4358-8ce9-ad24a7d4d2ad',
#     'entity_name': 'Microchip Technology Incorporated (MCHP)',
#     'entity_type': 'Equity'},
#    {'entity_id': '130b60d9-7078-4079-ba70-dc4b818aeaec',
#     'entity_name': 'Broadcom Inc. (AVGO)',
#     'entity_type': 'Equity'},
#    {'entity_id': '9d110065-1215-469b-81e0-1e626a74f5ad',
#     'entity_name': 'Intel Corporation (INTC)',
#     'entity_type': 'Equity'},
#    {'entity_id': '214032a1-c5d9-4976-8bcc-2518f577d55d',
#     'entity_name': 'KLA-Tencor Corporation (KLAC)',
#     'entity_type': 'Equity'},
#    {'entity_id': '3bf226be-0104-4c01-9310-f3877f46d475',
#     'entity_name': 'Viacom, Inc. (VIAB)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'Morgan Stanley Technology, Media & Telecom Conferences Start Date',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Industry Conferences',
#   'entity_aliases': []},
#  {'entity_id': 'bde993d1-46a7-42d7-9cd2-184cccbea394',
#   'related_entities': [{'entity_id': '37c53a09-309b-40bc-b165-90f0aac44366',
#     'entity_name': 'Alphabet Inc. (GOOG)',
#     'entity_type': 'Equity'},
#    {'entity_id': '6b7f93a8-cb9b-4358-a2a8-a1152377f4fc',
#     'entity_name': 'Altaba Inc. (AABA)',
#     'entity_type': 'Equity'},
#    {'entity_id': '42db86e9-808f-4ec6-a2ed-d5c9b8e4cdbc',
#     'entity_name': 'AT&T Inc. (T)',
#     'entity_type': 'Equity'},
#    {'entity_id': '6a000ac2-e348-4542-a4d0-d534578f476a',
#     'entity_name': 'Industry Conferences',
#     'entity_type': 'TimelineType'},
#    {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc',
#     'entity_name': 'Apple Inc. (AAPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'cfb73e32-4fa8-4701-898c-6c39279bbdb4',
#     'entity_name': 'Amazon.com, Inc. (AMZN)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'd8ce5287-c2c4-4c5a-8ec7-334b8213de4b',
#     'entity_name': 'Facebook, Inc. (FB)',
#     'entity_type': 'Equity'},
#    {'entity_id': '0f154c5b-90a2-40fc-89a0-c9fce7d05676',
#     'entity_name': 'Verizon Communications Inc. (VZ)',
#     'entity_type': 'Equity'},
#    {'entity_id': '06826ee5-f5e2-4342-9bee-1a546db3b03b',
#     'entity_name': 'Microsoft Corporation (MSFT)',
#     'entity_type': 'Equity'},
#    {'entity_id': '4803b915-8868-488a-9686-e6157ad9b6ea',
#     'entity_name': 'Berkshire Hathaway Inc. (BRK.A)',
#     'entity_type': 'Equity'},
#    {'entity_id': '8e971eb5-6854-4969-abe9-26d89a01cf35',
#     'entity_name': 'HP Inc. (HPQ)',
#     'entity_type': 'Equity'},
#    {'entity_id': '7e8cac76-7eb3-4d15-953a-44703385819b',
#     'entity_name': 'PayPal Holdings, Inc. (PYPL)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'fdd3dc99-a65c-4fe9-8cfe-0df9dd24138f',
#     'entity_name': 'Sprint Corporation (S)',
#     'entity_type': 'Equity'},
#    {'entity_id': 'c03414b5-bf25-4f64-b5c8-ae50fc5b9e14',
#     'entity_name': 'Alphabet Inc. (GOOG.L)',
#     'entity_type': 'Equity'},
#    {'entity_id': '8a585ecf-fbe7-4e90-a7ce-6d2844ee91a5',
#     'entity_name': 'T-Mobile US, Inc. (TMUS)',
#     'entity_type': 'Equity'},
#    {'entity_id': '702350dc-6ef8-4310-a5ab-a7aa5e7af188',
#     'entity_name': 'Citrix Systems, Inc. (CTXS)',
#     'entity_type': 'Equity'},
#    {'entity_id': '9df60204-2c65-4d05-8d09-4b1edd614c27',
#     'entity_name': 'eBay Inc. (EBAY)',
#     'entity_type': 'Equity'},
#    {'entity_id': '013dacaa-c885-4897-b72a-05b2e0738152',
#     'entity_name': 'Berkshire Hathaway Inc. (BRK.B)',
#     'entity_type': 'Equity'},
#    {'entity_id': '8145cd22-43cb-4911-8b91-d3fa8f69cc9d',
#     'entity_name': 'Netflix, Inc. (NFLX)',
#     'entity_type': 'Equity'}],
#   'entity_name': 'Allen & Company Sun Valley Conferences Start Date',
#   'entity_type': 'Timeline',
#   'timeline_type': 'Industry Conferences',
#   'entity_aliases': []}]

# %%
for i in check['data']:
    if 'entity_id' in i.keys():
        print(i)
# Out:
# {'entity_id': 'ec5a179d-ae08-4912-8bca-6a348baa2213', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'e8e36842-d63f-4d89-8523-f005396e2842', 'entity_name': 'Earnings', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. (AAPL) Earnings Releases', 'entity_type': 'Timeline', 'timeline_type': 'Earnings', 'entity_aliases': []}
# {'entity_id': '7244135a-f39a-4443-94ed-5508b580cf9d', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '96ab5874-3751-4045-b6f0-3ed4cce23935', 'entity_name': 'Corporate Guidance - Lowered', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Corporate Guidance - Lowered', 'entity_type': 'Timeline', 'timeline_type': 'Corporate Guidance - Lowered', 'entity_aliases': []}
# {'entity_id': 'e8479f2e-4cc4-43f7-8d9a-b3e8d056b4a0', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '32c7a8b3-5ba2-4054-9737-b648db6b4864', 'entity_name': 'Corporate Guidance - Raised', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Corporate Guidance - Raised', 'entity_type': 'Timeline', 'timeline_type': 'Corporate Guidance - Raised', 'entity_aliases': []}
# {'entity_id': '96b9e238-45f1-4949-855e-04312153f551', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '4c1d559f-6b9c-4dff-b050-d2676c8160d5', 'entity_name': 'Corporate Guidance - New/Confirmed', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Corporate Guidance - New/Confirmed', 'entity_type': 'Timeline', 'timeline_type': 'Corporate Guidance - New/Confirmed', 'entity_aliases': []}
# {'entity_id': 'b7f2edfa-4820-48e7-a96d-a11661e86a76', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'd60cbde2-4241-45aa-ae43-7d2a466362f9', 'entity_name': 'Regulatory Agency Inquiries', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Regulatory Agency Inquiries', 'entity_type': 'Timeline', 'timeline_type': 'Regulatory Agency Inquiries', 'entity_aliases': []}
# {'entity_id': 'c4df90c0-8a81-4fa5-9e1c-049c7d5989cd', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '45d7a5d8-cd0d-44ea-916c-7fcd1f54e3b0', 'entity_name': 'Delayed Earnings Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Delayed Earnings Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Delayed Earnings Announcements', 'entity_aliases': []}
# {'entity_id': '47d58960-8c89-451d-a16f-cf1b1c914523', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '9d14a825-6dce-468f-9e91-3edc69747bed', 'entity_name': 'Dividend Affirmations', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Dividend Affirmations', 'entity_type': 'Timeline', 'timeline_type': 'Dividend Affirmations', 'entity_aliases': []}
# {'entity_id': '16772c7e-bf18-4b8d-ad47-31cde847a17d', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'cfd874a8-74d1-4862-9c21-696a6764d030', 'entity_name': 'Dividend Increases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Dividend Increases', 'entity_type': 'Timeline', 'timeline_type': 'Dividend Increases', 'entity_aliases': []}
# {'entity_id': '1faae521-3ecc-4f83-bbab-294b56b8c075', 'related_entities': [{'entity_id': '3aab1ede-92b6-47f1-8deb-68acb1495884', 'entity_name': 'Annual General Meeting', 'entity_type': 'TimelineType'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}], 'entity_name': 'Apple Inc. Annual General Meeting', 'entity_type': 'Timeline', 'timeline_type': 'Annual General Meeting', 'entity_aliases': []}
# {'entity_id': '344e59f3-36a5-49d6-9c16-c04ac94b3376', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'f6d7f337-d991-49a0-af12-3e687b93ee51', 'entity_name': 'Discontinued Operations/Downsizings', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Discontinued Operations/Downsizings', 'entity_type': 'Timeline', 'timeline_type': 'Discontinued Operations/Downsizings', 'entity_aliases': []}
# {'entity_id': '063b5e60-ac28-46df-a69c-84333eae7438', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '36b9825e-983b-4a57-b9e5-02c8659b4d8d', 'entity_name': 'Delayed SEC Filings', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Delayed SEC Filings', 'entity_type': 'Timeline', 'timeline_type': 'Delayed SEC Filings', 'entity_aliases': []}
# {'entity_id': 'c745c041-b5df-4f16-b7a8-c3944990a09f', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '8e34b644-4190-4ad9-a748-8524fabd8de1', 'entity_name': 'Dividend Initiation', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Dividend Initiation', 'entity_type': 'Timeline', 'timeline_type': 'Dividend Initiation', 'entity_aliases': []}
# {'entity_id': 'db0c4d86-92ba-4bd2-8420-fcffa57ec503', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '465de126-df9a-4c18-a4e6-2ffcbddd99ae', 'entity_name': 'Buyback - Change in Plan Terms', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Buyback - Change in Plan Terms', 'entity_type': 'Timeline', 'timeline_type': 'Buyback - Change in Plan Terms', 'entity_aliases': []}
# {'entity_id': 'eb12cd47-1425-4358-8005-65e269d9c381', 'related_entities': [{'entity_id': '25014370-ce33-4e5c-8bde-14facbf65d32', 'entity_name': 'Buyback Tranche Update', 'entity_type': 'TimelineType'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}], 'entity_name': 'Apple Inc. Buyback Tranche Update', 'entity_type': 'Timeline', 'timeline_type': 'Buyback Tranche Update', 'entity_aliases': []}
# {'entity_id': 'c1829aba-9cd9-40e3-8ff6-6b2ccfa0a897', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fe570c2e-9c18-4946-bdd2-055b86c706fb', 'entity_name': 'Auditor Changes', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Auditor Changes', 'entity_type': 'Timeline', 'timeline_type': 'Auditor Changes', 'entity_aliases': []}
# {'entity_id': '9207db91-6aa7-4a77-99b3-0df81b020650', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'aa497aa3-0a61-4ef3-8617-ad2adf3c793b', 'entity_name': 'Name Changes', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Name Changes', 'entity_type': 'Timeline', 'timeline_type': 'Name Changes', 'entity_aliases': []}
# {'entity_id': '52813076-9932-48bb-8bf4-559558a8407f', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '01c26682-8ad3-4b82-9e9f-1003af896ad3', 'entity_name': 'Buyback Transaction Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Buyback Transaction Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Buyback Transaction Announcements', 'entity_aliases': []}
# {'entity_id': '0412b91c-cb81-48a6-8f07-b58f5f41ae83', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '48237fa3-836c-4254-802f-113ade5b43f2', 'entity_name': 'Capital Raises', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Fixed Income Issuance Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Capital Raises', 'entity_aliases': []}
# {'entity_id': '1dcaa221-1a3e-4808-9453-864af638ad43', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Key Personnel Role Start Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': '654753d1-e53e-43a5-acb7-6725f87912fc', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Key Personnel Role End Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': 'c989a05f-0585-4a6d-8f94-a67d9d9a994e', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Chief Operating Officer Start Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': '3489b1c7-70ec-446a-a568-9af68e8c4444', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Board Member Start Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': 'd407b8ec-e192-45ca-96ff-babb8c7e10bf', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Chief Operating Officer End Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': '6381301c-e36b-4911-9161-2756f45d3006', 'related_entities': [{'entity_id': '6205dfab-9d20-4933-b7ed-78b632bf1b64', 'entity_name': 'M&A', 'entity_type': 'TimelineType'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}], 'entity_name': 'Mergers and Acquisitions announcements by Apple Inc.', 'entity_type': 'Timeline', 'timeline_type': 'M&A', 'entity_aliases': []}
# {'entity_id': '3e602bda-08f8-4a3f-8f8a-ac8c42ed5a26', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '650505b8-ead1-45ee-93ba-7369a49219c9', 'entity_name': 'Communications', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. CEO Speeches', 'entity_type': 'Timeline', 'timeline_type': 'Communications', 'entity_aliases': []}
# {'entity_id': '0330d0a6-8e39-4bc0-a962-824b75757a3a', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '650505b8-ead1-45ee-93ba-7369a49219c9', 'entity_name': 'Communications', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Board Member Speeches', 'entity_type': 'Timeline', 'timeline_type': 'Communications', 'entity_aliases': []}
# {'entity_id': '65467c7d-f78f-41f5-b779-fa0ecbddc941', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa491823-346f-4e45-b9b6-9752d242bff1', 'entity_name': 'Company Conference Presentations', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Company Conference Presentations', 'entity_type': 'Timeline', 'timeline_type': 'Company Conference Presentations', 'entity_aliases': []}
# {'entity_id': 'fc0551b2-9b3d-43a6-af5f-141a1f647a6a', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '650505b8-ead1-45ee-93ba-7369a49219c9', 'entity_name': 'Communications', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Chair Speeches', 'entity_type': 'Timeline', 'timeline_type': 'Communications', 'entity_aliases': []}
# {'entity_id': '51128f17-6d45-4187-b892-e4d9a91e38c8', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. CEO Start Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': 'b7a72d5c-31a5-4820-bf46-00ba586aa6e3', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Chief Technology Officer Start Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': '28147d2c-6ea6-41c0-b4d4-6c410ae86315', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Chair Start Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': '98ecc95d-3792-4b84-bdbc-341656bc1a35', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. CEO End Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': 'e64c6187-af8c-4a7d-9367-47b8373b905d', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Chief Technology Officer End Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': 'f31189df-c293-4696-92fd-a39860aa0f45', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Board Member End Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': '34037d65-96cb-49a5-a6b2-d41fdca36dad', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b4a615f1-8dfb-43e6-b66c-20473c33e9ea', 'entity_name': 'Personnel', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Inc. Chair End Dates', 'entity_type': 'Timeline', 'timeline_type': 'Personnel', 'entity_aliases': []}
# {'entity_id': '6726e83c-822f-4878-8358-4b476d993b5b', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}], 'entity_name': 'Fixed Income Issuances Closings for Apple', 'entity_type': 'Timeline', 'timeline_type': 'Fixed Income Issuance Closings by Company', 'entity_aliases': []}
# {'entity_id': '7b6164fe-b9d8-46ac-9960-433e8ed4c04d', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple iPhone Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': 'ceac9f82-b32a-4efc-85f3-6709b3f14292', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Global Product Releases and Events', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': 'cb83a2f2-17dc-4694-9669-1ef0bcf880ea', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '48237fa3-836c-4254-802f-113ade5b43f2', 'entity_name': 'Capital Raises', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Debt Raises', 'entity_type': 'Timeline', 'timeline_type': 'Capital Raises', 'entity_aliases': []}
# {'entity_id': '63b2bfed-fa63-4f54-af35-1af174721d43', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple iOS Operating System Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': 'afe37000-053b-4bad-9e82-6d2a7ca07ca3', 'related_entities': [{'entity_id': '6a000ac2-e348-4542-a4d0-d534578f476a', 'entity_name': 'Industry Conferences', 'entity_type': 'TimelineType'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161', 'entity_name': 'Tablets', 'entity_type': 'Concept'}], 'entity_name': 'Apple Worldwide Developers Conference (WWDC) begins', 'entity_type': 'Timeline', 'timeline_type': 'Industry Conferences', 'entity_aliases': []}
# {'entity_id': '41e3c935-d2e3-4b33-84b1-3935aa635425', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Global Product & Services Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '3b0febbb-c91d-4464-b7c7-3bd70411db10', 'related_entities': [{'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba', 'entity_name': 'NXP Semiconductors N.V. (NXPI)', 'entity_type': 'Equity'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple iMac Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': 'ae250a9a-3fd7-460a-9954-8bfb0bdd38e5', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple iPhone Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': '1fa5be9d-b949-4016-ae8a-4d664835c086', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Mac OS X Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': '3eadeab4-c7c0-4bb1-b299-5884bf4d79c9', 'related_entities': [{'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba', 'entity_name': 'NXP Semiconductors N.V. (NXPI)', 'entity_type': 'Equity'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Recall and Replacement Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': 'db42d512-f622-4529-a6f3-b9e4f8a9f5b0', 'related_entities': [{'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}, {'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba', 'entity_name': 'NXP Semiconductors N.V. (NXPI)', 'entity_type': 'Equity'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': 'e58aa3a4-44d2-46f0-bc15-81c58cea9174', 'entity_name': 'BlackBerry Limited (BB)', 'entity_type': 'Equity'}], 'entity_name': 'Apple iPhone New Generation Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '0c7731e6-f7f5-4572-9914-154ca9cab44c', 'related_entities': [{'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161', 'entity_name': 'Tablets', 'entity_type': 'Concept'}, {'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba', 'entity_name': 'NXP Semiconductors N.V. (NXPI)', 'entity_type': 'Equity'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple iPad Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': 'bd1ba551-ff1b-4ca9-8565-a9e599366556', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '434af9b7-3d9b-4a7f-a695-4a71e3050196', 'entity_name': 'Investor Activism', 'entity_type': 'TimelineType'}], 'entity_name': 'Carl Icahn Apple Investment', 'entity_type': 'Timeline', 'timeline_type': 'Investor Activism', 'entity_aliases': []}
# {'entity_id': '94ef4c8c-6890-440f-8c6b-6779e693b656', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple New Product Line Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '25342dcc-e8ac-4694-8e25-8725a4cb001c', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '2b96628d-5113-4549-a19a-3ba15926a0ce', 'entity_name': 'Partnerships', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Corporate Partnership Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Partnerships', 'entity_aliases': []}
# {'entity_id': '44a2dd7e-3439-4102-8885-a55c528581d7', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple iOS Operating System Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': '8e913f51-13cb-487f-b231-7d77c3078441', 'related_entities': [{'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba', 'entity_name': 'NXP Semiconductors N.V. (NXPI)', 'entity_type': 'Equity'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': 'e58aa3a4-44d2-46f0-bc15-81c58cea9174', 'entity_name': 'BlackBerry Limited (BB)', 'entity_type': 'Equity'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple iPhone New Generation Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': 'e245d755-4b4a-4dab-8ff3-7c48706b8d57', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple New Product Line Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': '37f41f98-2030-45fb-a5a8-e8692baab0c5', 'related_entities': [{'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}, {'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161', 'entity_name': 'Tablets', 'entity_type': 'Concept'}, {'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba', 'entity_name': 'NXP Semiconductors N.V. (NXPI)', 'entity_type': 'Equity'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}], 'entity_name': 'Apple iPad Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '71972f6c-b1bc-4082-85a0-27ed88c7a647', 'related_entities': [{'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba', 'entity_name': 'NXP Semiconductors N.V. (NXPI)', 'entity_type': 'Equity'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple iMac Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '80609696-b8df-43ab-b5e9-30b1e5b6eb43', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '434af9b7-3d9b-4a7f-a695-4a71e3050196', 'entity_name': 'Investor Activism', 'entity_type': 'TimelineType'}], 'entity_name': 'Carl Icahn Statements/Letters on Apple', 'entity_type': 'Timeline', 'timeline_type': 'Investor Activism', 'entity_aliases': []}
# {'entity_id': '6f88160f-ba7a-4ff1-b1fe-4c14a0c16722', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '43b091dd-04a9-4c7f-b5d9-217e10f6fb28', 'entity_name': 'Penalties', 'entity_type': 'TimelineType'}], 'entity_name': 'Fines Paid by Apple', 'entity_type': 'Timeline', 'timeline_type': 'Penalties', 'entity_aliases': []}
# {'entity_id': '014015c0-fd1e-4f7a-9465-ae2e7fadb9b5', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Original Series Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': 'c8019ac9-8f7e-4e0c-905a-9f233be30e27', 'related_entities': [{'entity_id': 'f1cee052-cf52-4344-b42a-92ccb2764f97', 'entity_name': 'Expansions', 'entity_type': 'TimelineType'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '96d1bc76-938e-41a2-ac17-be05a71c98ae', 'entity_name': 'Digital Payments', 'entity_type': 'Concept'}], 'entity_name': 'Apple Pay New Country Launches', 'entity_type': 'Timeline', 'timeline_type': 'Expansions', 'entity_aliases': []}
# {'entity_id': '19850a72-08b2-48e0-bd27-2338850f27d0', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '96d1bc76-938e-41a2-ac17-be05a71c98ae', 'entity_name': 'Digital Payments', 'entity_type': 'Concept'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Pay New Country Launch Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '0b50c4f6-9804-4e3a-aac1-7540a23daa62', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': 'fa81c667-c139-4938-9a82-d209d78b54b6', 'entity_name': 'Lawsuits', 'entity_type': 'TimelineType'}, {'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161', 'entity_name': 'Tablets', 'entity_type': 'Concept'}], 'entity_name': 'Milestones in the Apple-FBI Encryption Case', 'entity_type': 'Timeline', 'timeline_type': 'Lawsuits', 'entity_aliases': []}
# {'entity_id': 'cab67e85-9983-4e9a-bce7-00f587d866fa', 'related_entities': [{'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba', 'entity_name': 'NXP Semiconductors N.V. (NXPI)', 'entity_type': 'Equity'}, {'entity_id': '6a000ac2-e348-4542-a4d0-d534578f476a', 'entity_name': 'Industry Conferences', 'entity_type': 'TimelineType'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}], 'entity_name': 'Apple Media Events', 'entity_type': 'Timeline', 'timeline_type': 'Industry Conferences', 'entity_aliases': []}
# {'entity_id': 'a60792f8-a4d7-405e-909d-f7da5857f569', 'related_entities': [{'entity_id': '623b20a9-deeb-4daa-9da6-95e3927c9350', 'entity_name': 'Level 3 Parent, LLC (LVLT)', 'entity_type': 'Equity'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'New Apple Services Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '1f73c96f-4861-49c7-a161-400c74979f6e', 'related_entities': [{'entity_id': '623b20a9-deeb-4daa-9da6-95e3927c9350', 'entity_name': 'Level 3 Parent, LLC (LVLT)', 'entity_type': 'Equity'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'New Apple Services Release Dates', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': 'ae923559-ad94-49e2-85d2-20043f20b481', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '650505b8-ead1-45ee-93ba-7369a49219c9', 'entity_name': 'Communications', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Open Letters', 'entity_type': 'Timeline', 'timeline_type': 'Communications', 'entity_aliases': []}
# {'entity_id': '47acbab2-3e98-47fc-9280-97025b1ce4e7', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple MacBook Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': 'a0debd16-7178-4925-ba7e-2b4b82eded76', 'related_entities': [{'entity_id': '6205dfab-9d20-4933-b7ed-78b632bf1b64', 'entity_name': 'M&A', 'entity_type': 'TimelineType'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}], 'entity_name': 'Confirmed Apple Investments over $1M', 'entity_type': 'Timeline', 'timeline_type': 'M&A', 'entity_aliases': []}
# {'entity_id': '7f9261b6-a6d8-485f-80aa-1acb6153da0a', 'related_entities': [{'entity_id': '5e4ed7a7-1926-491c-85fb-b05c835dc493', 'entity_name': 'Samsung Electronics Co., Ltd. (A005930)', 'entity_type': 'Equity'}, {'entity_id': 'fa81c667-c139-4938-9a82-d209d78b54b6', 'entity_name': 'Lawsuits', 'entity_type': 'TimelineType'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161', 'entity_name': 'Tablets', 'entity_type': 'Concept'}], 'entity_name': 'Developments in Apple-Samsung Legal Disputes (International)', 'entity_type': 'Timeline', 'timeline_type': 'Lawsuits', 'entity_aliases': []}
# {'entity_id': 'cb12405c-ef6d-4150-a69e-691132b1357f', 'related_entities': [{'entity_id': '7754b877-b037-423b-8ab5-d0aba6031a0b', 'entity_name': 'US Dollar (Next day)', 'entity_type': 'Currency'}, {'entity_id': 'fa81c667-c139-4938-9a82-d209d78b54b6', 'entity_name': 'Lawsuits', 'entity_type': 'TimelineType'}, {'entity_id': '229c72a7-d35a-4290-8853-f97248c55243', 'entity_name': 'United States of America', 'entity_type': 'Region'}, {'entity_id': '8a384f5c-4673-4c5e-a776-4780f4316161', 'entity_name': 'Tablets', 'entity_type': 'Concept'}, {'entity_id': '5568e897-3cbd-4cbd-b038-7a740d43f55f', 'entity_name': 'US Dollar', 'entity_type': 'Currency'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': '5e4ed7a7-1926-491c-85fb-b05c835dc493', 'entity_name': 'Samsung Electronics Co., Ltd. (A005930)', 'entity_type': 'Equity'}], 'entity_name': 'Developments in Apple-Samsung Legal Disputes (U.S.)', 'entity_type': 'Timeline', 'timeline_type': 'Lawsuits', 'entity_aliases': []}
# {'entity_id': 'a62b9358-f49d-4c49-bacc-f99ca7f83879', 'related_entities': [{'entity_id': '03b45cc0-f14a-4898-968b-8b8f60a3d64c', 'entity_name': 'Yuan Renminbi', 'entity_type': 'Currency'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b1e2b7e1-910b-4d85-b36c-ec995e0d2fa6', 'entity_name': 'China', 'entity_type': 'Region'}, {'entity_id': '43b091dd-04a9-4c7f-b5d9-217e10f6fb28', 'entity_name': 'Penalties', 'entity_type': 'TimelineType'}], 'entity_name': 'China Bans Apple Products or Services', 'entity_type': 'Timeline', 'timeline_type': 'Penalties', 'entity_aliases': []}
# {'entity_id': '7bebfb14-f5e5-4398-91b4-d10ca316574e', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '4f17c86f-5269-46ba-8cd7-47e927fe254b', 'entity_name': 'Product Outages', 'entity_type': 'TimelineType'}], 'entity_name': 'Widely Reported Apple Service and Product Outages', 'entity_type': 'Timeline', 'timeline_type': 'Product Outages', 'entity_aliases': []}
# {'entity_id': '4ed741de-4e6a-4bd6-90a1-085baa3c1168', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '1f0667ed-3009-463a-9301-bfe158f863a8', 'entity_name': 'Wearables', 'entity_type': 'Concept'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple WatchOS Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': '0536b6f8-314a-4693-9712-e8031b4fb2dc', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '1f0667ed-3009-463a-9301-bfe158f863a8', 'entity_name': 'Wearables', 'entity_type': 'Concept'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Watch New Generation Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': '7599621b-a8fb-4f4b-9544-a01ae8d4e8c4', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}, {'entity_id': '1f0667ed-3009-463a-9301-bfe158f863a8', 'entity_name': 'Wearables', 'entity_type': 'Concept'}], 'entity_name': 'Apple Watch New Generation Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '561c60a1-6341-4c4f-b1cf-370468d1f810', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple MacBook Pro Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': 'f8bcbd7f-7f13-43be-b5c5-07503b6446ea', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': '569deaef-33c9-426f-a7c4-b392e94e0b1f', 'entity_name': 'Product Developments', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple iPhone Production Cuts', 'entity_type': 'Timeline', 'timeline_type': 'Product Developments', 'entity_aliases': []}
# {'entity_id': '31261ad7-a6fb-4d2b-9100-0a9696a5b5af', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Special Edition Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': 'fcd98482-d1f4-457e-9b9a-e0cbe2ccba56', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple MacBook Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': 'da32d6b3-456b-4dc5-b220-44dc19a594b0', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': '89a11e7c-b7a7-4692-8efe-7d33584e7fcf', 'entity_name': 'Contracts', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Supplier Cancellation Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Contracts', 'entity_aliases': []}
# {'entity_id': 'a66a18ff-95e1-4382-96af-d109f49d0ed5', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}, {'entity_id': '1f0667ed-3009-463a-9301-bfe158f863a8', 'entity_name': 'Wearables', 'entity_type': 'Concept'}], 'entity_name': 'Apple WatchOS Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '44a638ec-d5dd-442c-a039-f4fdc4b504b8', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'ec9ae1ac-33c6-4e44-b033-00377cb7b0d3', 'entity_name': 'Product Releases', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple MacBook Air Releases', 'entity_type': 'Timeline', 'timeline_type': 'Product Releases', 'entity_aliases': []}
# {'entity_id': '4d1db123-7a8c-4885-880b-ce1431482d62', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'e8f371b9-17a4-4c39-9d53-f79dce1ca63b', 'entity_name': 'Publicity', 'entity_type': 'TimelineType'}], 'entity_name': "Developments in Apple's Tax Avoidance Controversies", 'entity_type': 'Timeline', 'timeline_type': 'Publicity', 'entity_aliases': []}
# {'entity_id': 'cb9df46d-379d-4991-99e4-b0b35a8d846b', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '569deaef-33c9-426f-a7c4-b392e94e0b1f', 'entity_name': 'Product Developments', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple App Store Prices Changes', 'entity_type': 'Timeline', 'timeline_type': 'Product Developments', 'entity_aliases': []}
# {'entity_id': 'fa83ab0c-29fa-40b4-9726-eebd2be60cdb', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'fa23a8bc-07e2-4bf2-970c-de68b7c3f431', 'entity_name': 'Smartphones', 'entity_type': 'Concept'}, {'entity_id': '62ad3190-eb46-4824-bbe0-5e1ca3657fea', 'entity_name': 'QUALCOMM Incorporated (QCOM)', 'entity_type': 'Equity'}, {'entity_id': 'fa81c667-c139-4938-9a82-d209d78b54b6', 'entity_name': 'Lawsuits', 'entity_type': 'TimelineType'}], 'entity_name': 'Developments in Apple-Qualcomm Legal Disputes', 'entity_type': 'Timeline', 'timeline_type': 'Lawsuits', 'entity_aliases': []}
# {'entity_id': '221738ee-9e04-491c-9fd1-35da6e9ffe75', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Mac OS X Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '8179c835-93fd-4a97-85b1-01a51d4d8f1b', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple TV New Generation Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '09db9a44-b332-48b5-99a8-e5510148d85c', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple iMac Pro Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': 'a0e52593-1b20-474f-b695-02fbb736339d', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '79634c6f-4155-4307-8f73-31fe86f2601f', 'entity_name': 'Product Announcements', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple HomePod Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Product Announcements', 'entity_aliases': []}
# {'entity_id': '32556076-c26c-4eac-b979-fd15f998443a', 'related_entities': [{'entity_id': '03b45cc0-f14a-4898-968b-8b8f60a3d64c', 'entity_name': 'Yuan Renminbi', 'entity_type': 'Currency'}, {'entity_id': '89bba83b-63b5-4bce-8020-e5fb2470bf8b', 'entity_name': 'National Accounts', 'entity_type': 'TimelineType'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b1e2b7e1-910b-4d85-b36c-ec995e0d2fa6', 'entity_name': 'China', 'entity_type': 'Region'}], 'entity_name': 'Apple Greater China Quarterly Revenue Increases', 'entity_type': 'Timeline', 'timeline_type': 'National Accounts', 'entity_aliases': []}
# {'entity_id': 'e92db080-a6ad-494d-bac6-fe6f40c7b5cd', 'related_entities': [{'entity_id': '03b45cc0-f14a-4898-968b-8b8f60a3d64c', 'entity_name': 'Yuan Renminbi', 'entity_type': 'Currency'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'b1e2b7e1-910b-4d85-b36c-ec995e0d2fa6', 'entity_name': 'China', 'entity_type': 'Region'}, {'entity_id': 'e8e36842-d63f-4d89-8523-f005396e2842', 'entity_name': 'Earnings', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple Greater China Quarterly Revenue Decreases', 'entity_type': 'Timeline', 'timeline_type': 'Earnings', 'entity_aliases': []}
# {'entity_id': '5a9bbbbc-e082-4b40-a96b-9759de9b2431', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'f1cee052-cf52-4344-b42a-92ccb2764f97', 'entity_name': 'Expansions', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple First International Retail Store Openings', 'entity_type': 'Timeline', 'timeline_type': 'Expansions', 'entity_aliases': []}
# {'entity_id': '2a293e4a-0602-4fa9-a781-2b918e04c865', 'related_entities': [{'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'f1cee052-cf52-4344-b42a-92ccb2764f97', 'entity_name': 'Expansions', 'entity_type': 'TimelineType'}], 'entity_name': 'Apple First International Retail Store Announcements', 'entity_type': 'Timeline', 'timeline_type': 'Expansions', 'entity_aliases': []}
# ...
# {'entity_id': '3e056c9e-54d3-459b-95c6-d0f82c0c9eeb', 'related_entities': [{'entity_id': '03e7519b-cd37-4b57-8aa4-1fb582f370d7', 'entity_name': 'STMicroelectronics N.V. (STM)', 'entity_type': 'Equity'}, {'entity_id': 'ee30f339-7240-4c7f-b08f-dc0d8d543cc6', 'entity_name': 'Canon Inc. (7751)', 'entity_type': 'Equity'}, {'entity_id': 'b947ea63-eac3-4375-abee-333b1db74b85', 'entity_name': 'Oracle Corporation (ORCL)', 'entity_type': 'Equity'}, {'entity_id': 'b2d8e6ee-8713-4956-bd7b-444197636641', 'entity_name': 'Cognizant Technology Solutions Corporation (CTSH)', 'entity_type': 'Equity'}, {'entity_id': 'ecaf2b68-a90a-4a88-ae27-2a85572c3fce', 'entity_name': 'Finisar Corporation (FNSR)', 'entity_type': 'Equity'}, {'entity_id': 'd3ab7464-6819-4b43-afbb-073c0f5a6c1c', 'entity_name': 'Panasonic Corporation (6752)', 'entity_type': 'Equity'}, {'entity_id': '8e971eb5-6854-4969-abe9-26d89a01cf35', 'entity_name': 'HP Inc. (HPQ)', 'entity_type': 'Equity'}, {'entity_id': '0f154c5b-90a2-40fc-89a0-c9fce7d05676', 'entity_name': 'Verizon Communications Inc. (VZ)', 'entity_type': 'Equity'}, {'entity_id': '8a585ecf-fbe7-4e90-a7ce-6d2844ee91a5', 'entity_name': 'T-Mobile US, Inc. (TMUS)', 'entity_type': 'Equity'}, {'entity_id': '6522e9ca-4645-4ee3-9f01-8e41a54e66b8', 'entity_name': 'Comcast Corporation (CMCS.A)', 'entity_type': 'Equity'}, {'entity_id': '41d5fbe4-7e2a-4f5b-82f4-c81fe3de44a1', 'entity_name': 'Nexstar Media Group, Inc. (NXST)', 'entity_type': 'Equity'}, {'entity_id': '9d9b1c04-022e-47fe-af54-091908483897', 'entity_name': 'Adobe Systems Incorporated (ADBE)', 'entity_type': 'Equity'}, {'entity_id': '8145cd22-43cb-4911-8b91-d3fa8f69cc9d', 'entity_name': 'Netflix, Inc. (NFLX)', 'entity_type': 'Equity'}, {'entity_id': '6150860b-535d-41c3-bbf4-bacaae4c5403', 'entity_name': 'Xerox Corporation (XRX)', 'entity_type': 'Equity'}, {'entity_id': '37c53a09-309b-40bc-b165-90f0aac44366', 'entity_name': 'Alphabet Inc. (GOOG)', 'entity_type': 'Equity'}, {'entity_id': '42db86e9-808f-4ec6-a2ed-d5c9b8e4cdbc', 'entity_name': 'AT&T Inc. (T)', 'entity_type': 'Equity'}, {'entity_id': '5569f0a7-3703-4506-8e13-48da4fb0eaa4', 'entity_name': 'VMware, Inc. (VMW)', 'entity_type': 'Equity'}, {'entity_id': 'bff241df-9158-4a57-bcd3-3bae9b9680bb', 'entity_name': 'Texas Instruments Incorporated (TXN)', 'entity_type': 'Equity'}, {'entity_id': '0012e47e-cd4a-4630-83ab-7110123bbc07', 'entity_name': 'Canon Inc. (CAJ)', 'entity_type': 'Equity'}, {'entity_id': '0ebbdfd6-d8e0-4a55-b0fb-b66a1498832c', 'entity_name': 'Qorvo, Inc. (QRVO)', 'entity_type': 'Equity'}, {'entity_id': 'c03414b5-bf25-4f64-b5c8-ae50fc5b9e14', 'entity_name': 'Alphabet Inc. (GOOG.L)', 'entity_type': 'Equity'}, {'entity_id': 'fe923b8e-7e31-4a47-8976-a5d8fff1867a', 'entity_name': 'Applied Materials, Inc. (AMAT)', 'entity_type': 'Equity'}, {'entity_id': 'db4dfc5e-0df9-4034-b261-78b1b8786f9c', 'entity_name': 'Accenture plc (ACN)', 'entity_type': 'Equity'}, {'entity_id': '6a000ac2-e348-4542-a4d0-d534578f476a', 'entity_name': 'Industry Conferences', 'entity_type': 'TimelineType'}, {'entity_id': 'fa4c20cc-88c8-4c84-8783-587d92e2640d', 'entity_name': 'Alibaba Group Holding Limited (BABA)', 'entity_type': 'Equity'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': '8041834a-3a48-4d89-a36f-304f16bbf8a5', 'entity_name': 'The Interpublic Group of Companies, Inc. (IPG)', 'entity_type': 'Equity'}, {'entity_id': 'd017caaf-3b4d-4920-9e1a-58a46d6ba20e', 'entity_name': 'F5 Networks, Inc. (FFIV)', 'entity_type': 'Equity'}, {'entity_id': 'e84989bf-334a-4889-9ee7-f283ed54fd9a', 'entity_name': 'SAP SE (SAP)', 'entity_type': 'Equity'}, {'entity_id': 'c6bb679a-4633-4fb0-844a-2ae41abef3ba', 'entity_name': 'NXP Semiconductors N.V. (NXPI)', 'entity_type': 'Equity'}, {'entity_id': '06e0290b-ffdf-44a2-9a78-29052e07cb69', 'entity_name': 'STMicroelectronics N.V. (STM)', 'entity_type': 'Equity'}, {'entity_id': 'edf557cc-da2c-4db7-8e15-7a60da428082', 'entity_nam ...
# {'entity_id': '8529ac0b-4192-42b4-89b5-f626a308a001', 'related_entities': [{'entity_id': '03e7519b-cd37-4b57-8aa4-1fb582f370d7', 'entity_name': 'STMicroelectronics N.V. (STM)', 'entity_type': 'Equity'}, {'entity_id': 'ee30f339-7240-4c7f-b08f-dc0d8d543cc6', 'entity_name': 'Canon Inc. (7751)', 'entity_type': 'Equity'}, {'entity_id': 'b947ea63-eac3-4375-abee-333b1db74b85', 'entity_name': 'Oracle Corporation (ORCL)', 'entity_type': 'Equity'}, {'entity_id': 'b2d8e6ee-8713-4956-bd7b-444197636641', 'entity_name': 'Cognizant Technology Solutions Corporation (CTSH)', 'entity_type': 'Equity'}, {'entity_id': '28c50de7-842a-4153-83dd-23b1ef6078e7', 'entity_name': 'Visa Inc. (V)', 'entity_type': 'Equity'}, {'entity_id': 'cfb73e32-4fa8-4701-898c-6c39279bbdb4', 'entity_name': 'Amazon.com, Inc. (AMZN)', 'entity_type': 'Equity'}, {'entity_id': '091a264f-dbf1-4090-9fd4-496f7c336f04', 'entity_name': 'Qurate Retail, Inc. (LVNTA)', 'entity_type': 'Equity'}, {'entity_id': 'ecaf2b68-a90a-4a88-ae27-2a85572c3fce', 'entity_name': 'Finisar Corporation (FNSR)', 'entity_type': 'Equity'}, {'entity_id': 'd3ab7464-6819-4b43-afbb-073c0f5a6c1c', 'entity_name': 'Panasonic Corporation (6752)', 'entity_type': 'Equity'}, {'entity_id': '8e971eb5-6854-4969-abe9-26d89a01cf35', 'entity_name': 'HP Inc. (HPQ)', 'entity_type': 'Equity'}, {'entity_id': 'fdd3dc99-a65c-4fe9-8cfe-0df9dd24138f', 'entity_name': 'Sprint Corporation (S)', 'entity_type': 'Equity'}, {'entity_id': '8a585ecf-fbe7-4e90-a7ce-6d2844ee91a5', 'entity_name': 'T-Mobile US, Inc. (TMUS)', 'entity_type': 'Equity'}, {'entity_id': 'bfd4330b-6596-4e94-9884-794e16506127', 'entity_name': 'WEX Inc. (WEX)', 'entity_type': 'Equity'}, {'entity_id': '1b46389f-0c72-4f34-97f9-00abc32f9e83', 'entity_name': 'International Business Machines Corporation (IBM)', 'entity_type': 'Equity'}, {'entity_id': '6522e9ca-4645-4ee3-9f01-8e41a54e66b8', 'entity_name': 'Comcast Corporation (CMCS.A)', 'entity_type': 'Equity'}, {'entity_id': 'c1fbff86-395b-465e-a611-d35e6f5dc1dd', 'entity_name': 'NTT DOCOMO, INC. (9437)', 'entity_type': 'Equity'}, {'entity_id': '41d5fbe4-7e2a-4f5b-82f4-c81fe3de44a1', 'entity_name': 'Nexstar Media Group, Inc. (NXST)', 'entity_type': 'Equity'}, {'entity_id': '9d9b1c04-022e-47fe-af54-091908483897', 'entity_name': 'Adobe Systems Incorporated (ADBE)', 'entity_type': 'Equity'}, {'entity_id': '8145cd22-43cb-4911-8b91-d3fa8f69cc9d', 'entity_name': 'Netflix, Inc. (NFLX)', 'entity_type': 'Equity'}, {'entity_id': '6150860b-535d-41c3-bbf4-bacaae4c5403', 'entity_name': 'Xerox Corporation (XRX)', 'entity_type': 'Equity'}, {'entity_id': '37c53a09-309b-40bc-b165-90f0aac44366', 'entity_name': 'Alphabet Inc. (GOOG)', 'entity_type': 'Equity'}, {'entity_id': '6952e1b1-cb13-4465-9f54-56d6145d9068', 'entity_name': 'Micron Technology, Inc. (MU)', 'entity_type': 'Equity'}, {'entity_id': '42db86e9-808f-4ec6-a2ed-d5c9b8e4cdbc', 'entity_name': 'AT&T Inc. (T)', 'entity_type': 'Equity'}, {'entity_id': '941ef5a5-19cd-436d-a8df-18af60742539', 'entity_name': 'Skyworks Solutions, Inc. (SWKS)', 'entity_type': 'Equity'}, {'entity_id': '5569f0a7-3703-4506-8e13-48da4fb0eaa4', 'entity_name': 'VMware, Inc. (VMW)', 'entity_type': 'Equity'}, {'entity_id': 'bff241df-9158-4a57-bcd3-3bae9b9680bb', 'entity_name': 'Texas Instruments Incorporated (TXN)', 'entity_type': 'Equity'}, {'entity_id': '0012e47e-cd4a-4630-83ab-7110123bbc07', 'entity_name': 'Canon Inc. (CAJ)', 'entity_type': 'Equity'}, {'entity_id': '5d65fe2b-85a4-450a-a042-ba37ecf04b2c', 'entity_name': 'Mercadolibre, Inc. (MELI)', 'entity_type': 'Equity'}, {'entity_id': 'a48b489e-8156-4175-9d65-d6f835393aa5', 'entity_name': 'NTT DOCOMO, INC. (DCM)', 'entity_type': 'Equity'}, {'entity_id': 'd889ddda-8b36-4cc4-b622-f9ca84fd488c', 'entity_name': 'SoftBank Group Corp. (9984)', 'entity_type': 'Equity'}, {'entity_id': '0ebbdfd6-d8e0-4a55-b0fb-b66a1498832c', 'entity_name': 'Qorvo, Inc. (QRVO)', 'entity_type': 'Equity'}, {'entity_id': '1c000b74-d814-49b3-8f7c-e8c0815ce6c7', 'entity_name': 'Nippon Telegra ...
# {'entity_id': '574e43f7-d88b-4e8e-8b0f-71faa4a67039', 'related_entities': [{'entity_id': '03e7519b-cd37-4b57-8aa4-1fb582f370d7', 'entity_name': 'STMicroelectronics N.V. (STM)', 'entity_type': 'Equity'}, {'entity_id': 'ee30f339-7240-4c7f-b08f-dc0d8d543cc6', 'entity_name': 'Canon Inc. (7751)', 'entity_type': 'Equity'}, {'entity_id': 'b947ea63-eac3-4375-abee-333b1db74b85', 'entity_name': 'Oracle Corporation (ORCL)', 'entity_type': 'Equity'}, {'entity_id': 'b2d8e6ee-8713-4956-bd7b-444197636641', 'entity_name': 'Cognizant Technology Solutions Corporation (CTSH)', 'entity_type': 'Equity'}, {'entity_id': 'cfb73e32-4fa8-4701-898c-6c39279bbdb4', 'entity_name': 'Amazon.com, Inc. (AMZN)', 'entity_type': 'Equity'}, {'entity_id': '091a264f-dbf1-4090-9fd4-496f7c336f04', 'entity_name': 'Qurate Retail, Inc. (LVNTA)', 'entity_type': 'Equity'}, {'entity_id': 'ecaf2b68-a90a-4a88-ae27-2a85572c3fce', 'entity_name': 'Finisar Corporation (FNSR)', 'entity_type': 'Equity'}, {'entity_id': 'd3ab7464-6819-4b43-afbb-073c0f5a6c1c', 'entity_name': 'Panasonic Corporation (6752)', 'entity_type': 'Equity'}, {'entity_id': '8e971eb5-6854-4969-abe9-26d89a01cf35', 'entity_name': 'HP Inc. (HPQ)', 'entity_type': 'Equity'}, {'entity_id': 'fdd3dc99-a65c-4fe9-8cfe-0df9dd24138f', 'entity_name': 'Sprint Corporation (S)', 'entity_type': 'Equity'}, {'entity_id': '8a585ecf-fbe7-4e90-a7ce-6d2844ee91a5', 'entity_name': 'T-Mobile US, Inc. (TMUS)', 'entity_type': 'Equity'}, {'entity_id': '6522e9ca-4645-4ee3-9f01-8e41a54e66b8', 'entity_name': 'Comcast Corporation (CMCS.A)', 'entity_type': 'Equity'}, {'entity_id': '41d5fbe4-7e2a-4f5b-82f4-c81fe3de44a1', 'entity_name': 'Nexstar Media Group, Inc. (NXST)', 'entity_type': 'Equity'}, {'entity_id': '9d9b1c04-022e-47fe-af54-091908483897', 'entity_name': 'Adobe Systems Incorporated (ADBE)', 'entity_type': 'Equity'}, {'entity_id': '8145cd22-43cb-4911-8b91-d3fa8f69cc9d', 'entity_name': 'Netflix, Inc. (NFLX)', 'entity_type': 'Equity'}, {'entity_id': '6150860b-535d-41c3-bbf4-bacaae4c5403', 'entity_name': 'Xerox Corporation (XRX)', 'entity_type': 'Equity'}, {'entity_id': '37c53a09-309b-40bc-b165-90f0aac44366', 'entity_name': 'Alphabet Inc. (GOOG)', 'entity_type': 'Equity'}, {'entity_id': '6952e1b1-cb13-4465-9f54-56d6145d9068', 'entity_name': 'Micron Technology, Inc. (MU)', 'entity_type': 'Equity'}, {'entity_id': '42db86e9-808f-4ec6-a2ed-d5c9b8e4cdbc', 'entity_name': 'AT&T Inc. (T)', 'entity_type': 'Equity'}, {'entity_id': '941ef5a5-19cd-436d-a8df-18af60742539', 'entity_name': 'Skyworks Solutions, Inc. (SWKS)', 'entity_type': 'Equity'}, {'entity_id': '5569f0a7-3703-4506-8e13-48da4fb0eaa4', 'entity_name': 'VMware, Inc. (VMW)', 'entity_type': 'Equity'}, {'entity_id': 'bff241df-9158-4a57-bcd3-3bae9b9680bb', 'entity_name': 'Texas Instruments Incorporated (TXN)', 'entity_type': 'Equity'}, {'entity_id': '0012e47e-cd4a-4630-83ab-7110123bbc07', 'entity_name': 'Canon Inc. (CAJ)', 'entity_type': 'Equity'}, {'entity_id': '5d65fe2b-85a4-450a-a042-ba37ecf04b2c', 'entity_name': 'Mercadolibre, Inc. (MELI)', 'entity_type': 'Equity'}, {'entity_id': '00575a39-118f-46ad-b498-1427b64baba0', 'entity_name': 'Morgan Stanley (MS)', 'entity_type': 'Equity'}, {'entity_id': '404ae198-2d24-41a7-80b5-ec9aed82ca6a', 'entity_name': 'Equinix, Inc. (REIT) (EQIX)', 'entity_type': 'Equity'}, {'entity_id': '0ebbdfd6-d8e0-4a55-b0fb-b66a1498832c', 'entity_name': 'Qorvo, Inc. (QRVO)', 'entity_type': 'Equity'}, {'entity_id': 'c03414b5-bf25-4f64-b5c8-ae50fc5b9e14', 'entity_name': 'Alphabet Inc. (GOOG.L)', 'entity_type': 'Equity'}, {'entity_id': 'fe923b8e-7e31-4a47-8976-a5d8fff1867a', 'entity_name': 'Applied Materials, Inc. (AMAT)', 'entity_type': 'Equity'}, {'entity_id': '0f94e2ac-f556-4bcc-86b1-7182fec9a284', 'entity_name': 'Xilinx, Inc. (XLNX)', 'entity_type': 'Equity'}, {'entity_id': 'db4dfc5e-0df9-4034-b261-78b1b8786f9c', 'entity_name': 'Accenture plc (ACN)', 'entity_type': 'Equity'}, {'entity_id': '6a000ac2-e348-4542-a4d0-d534578f476a', 'entity_name': 'Industry Conferences', 'en ...
# {'entity_id': 'bde993d1-46a7-42d7-9cd2-184cccbea394', 'related_entities': [{'entity_id': '37c53a09-309b-40bc-b165-90f0aac44366', 'entity_name': 'Alphabet Inc. (GOOG)', 'entity_type': 'Equity'}, {'entity_id': '6b7f93a8-cb9b-4358-a2a8-a1152377f4fc', 'entity_name': 'Altaba Inc. (AABA)', 'entity_type': 'Equity'}, {'entity_id': '42db86e9-808f-4ec6-a2ed-d5c9b8e4cdbc', 'entity_name': 'AT&T Inc. (T)', 'entity_type': 'Equity'}, {'entity_id': '6a000ac2-e348-4542-a4d0-d534578f476a', 'entity_name': 'Industry Conferences', 'entity_type': 'TimelineType'}, {'entity_id': 'f9d09c10-c6de-4e8f-9624-996774888bcc', 'entity_name': 'Apple Inc. (AAPL)', 'entity_type': 'Equity'}, {'entity_id': 'cfb73e32-4fa8-4701-898c-6c39279bbdb4', 'entity_name': 'Amazon.com, Inc. (AMZN)', 'entity_type': 'Equity'}, {'entity_id': 'd8ce5287-c2c4-4c5a-8ec7-334b8213de4b', 'entity_name': 'Facebook, Inc. (FB)', 'entity_type': 'Equity'}, {'entity_id': '0f154c5b-90a2-40fc-89a0-c9fce7d05676', 'entity_name': 'Verizon Communications Inc. (VZ)', 'entity_type': 'Equity'}, {'entity_id': '06826ee5-f5e2-4342-9bee-1a546db3b03b', 'entity_name': 'Microsoft Corporation (MSFT)', 'entity_type': 'Equity'}, {'entity_id': '4803b915-8868-488a-9686-e6157ad9b6ea', 'entity_name': 'Berkshire Hathaway Inc. (BRK.A)', 'entity_type': 'Equity'}, {'entity_id': '8e971eb5-6854-4969-abe9-26d89a01cf35', 'entity_name': 'HP Inc. (HPQ)', 'entity_type': 'Equity'}, {'entity_id': '7e8cac76-7eb3-4d15-953a-44703385819b', 'entity_name': 'PayPal Holdings, Inc. (PYPL)', 'entity_type': 'Equity'}, {'entity_id': 'fdd3dc99-a65c-4fe9-8cfe-0df9dd24138f', 'entity_name': 'Sprint Corporation (S)', 'entity_type': 'Equity'}, {'entity_id': 'c03414b5-bf25-4f64-b5c8-ae50fc5b9e14', 'entity_name': 'Alphabet Inc. (GOOG.L)', 'entity_type': 'Equity'}, {'entity_id': '8a585ecf-fbe7-4e90-a7ce-6d2844ee91a5', 'entity_name': 'T-Mobile US, Inc. (TMUS)', 'entity_type': 'Equity'}, {'entity_id': '702350dc-6ef8-4310-a5ab-a7aa5e7af188', 'entity_name': 'Citrix Systems, Inc. (CTXS)', 'entity_type': 'Equity'}, {'entity_id': '9df60204-2c65-4d05-8d09-4b1edd614c27', 'entity_name': 'eBay Inc. (EBAY)', 'entity_type': 'Equity'}, {'entity_id': '013dacaa-c885-4897-b72a-05b2e0738152', 'entity_name': 'Berkshire Hathaway Inc. (BRK.B)', 'entity_type': 'Equity'}, {'entity_id': '8145cd22-43cb-4911-8b91-d3fa8f69cc9d', 'entity_name': 'Netflix, Inc. (NFLX)', 'entity_type': 'Equity'}], 'entity_name': 'Allen & Company Sun Valley Conferences Start Date', 'entity_type': 'Timeline', 'timeline_type': 'Industry Conferences', 'entity_aliases': []}

# %%
import os

import pandas as pd
import requests


def _api_result_to_frame(api_result):
    """Convert API result into dataframe"""
    ordered_columns = [c['key'] for c in api_result['metadata']]
    # Create the dataframe
    return api_result['data']
    df = pd.DataFrame(api_result['data'])
    
    existence_filtered_columns = [c for c in ordered_columns if c in df.columns]
    reordered_frame = df[existence_filtered_columns]

    for column in api_result['metadata']:
        if column['key'] not in reordered_frame.columns:
            continue
        if column['unit'] == 'DateTime' or column['unit'] == 'Date':
            reordered_frame[column['key']] = pd.to_datetime(reordered_frame[column['key']])
    return reordered_frame


class _KenshoGraphClient(object):
    """Basic implementation of the Kensho Graph API client"""

    def __init__(self, host, api_key, converter_func, retries=1):
        """Initialize the client"""
        self._host = host
        self._api_key = api_key
        self._retries = retries
        self._converter_func = converter_func

    def list_entity_classes(self):
        """List all available entity classes"""
        return self._get_json_or_raise('list_entity_classes')

    def get_class_relationships(self, class_name):
        """Return all potential relationships of an entity of this class"""
        return self._get_json_or_raise(
            'get_class_relationships', class_name=class_name)

    def search_entities(self, class_name, search_string):
        """Search entities of the class_name that match search_string"""
        return self._get_json_or_raise(
            'search_entities', class_name=class_name, search_string=search_string)

    def list_entities_of_class(self, class_name):
        """List all entities of class"""
        return self._get_json_or_raise(
            'list_entities_of_class', class_name=class_name)

    def get_entity(self, entity_id):
        """Get entity by id"""
        return self._get_json_or_raise('get_entity', entity_id=entity_id)

    def get_related_entities(self, entity_id, relationship):
        """Get all entities related by one identified by entity_id by 'relationship'"""
        return self._get_json_or_raise(
            'get_related_entities', entity_id=entity_id, relationship=relationship)

    def get_timeline(self, timeline_id, start_date=None, end_date=None):
        """Get all events in a timeline. Optionally bound by start and end dates"""
        return self._get_json_or_raise(
            'get_timeline', timeline_id=timeline_id, start_date=start_date, end_date=end_date)

    def get_calendar(self, start_date, end_date):
        """Get all events happening in the interval [start_date, end_date)"""
        return self._get_json_or_raise('get_calendar', start_date=start_date, end_date=end_date)

    def get_ongoing_episodes(self, start_date, end_date):
        """Get all episodes ongoing in the interval [start_date, end_date)"""
        return self._get_json_or_raise(
            'get_ongoing_episodes', start_date=start_date, end_date=end_date)

    def translate_asset_id(self, id_type, asset_id):
        """Given an identification string for an asset return all known identifiers"""
        return self._get_json_or_raise('translate_asset_id', id_type=id_type, asset_id=asset_id)

    def list_timeline_types(self):
        """Given an identification string for an asset return all known identifiers"""
        return self._get_json_or_raise('list_timeline_types')

    
    def _get_json_or_raise(self, function, **kwargs):
        """Get json from a given url. Uses get_with_retries underneath"""
        session = requests.Session()
        session.mount('https://', requests.adapters.HTTPAdapter(max_retries=self._retries))
        full_url = '/'.join([self._host.rstrip('/'), function.lstrip('/')])
        headers = {
            'Authorization': 'Token {}'.format(self._api_key),
            'Content-Type': 'application/json'
        }
        response = session.get(full_url, headers=headers, params=kwargs)
        response.raise_for_status()
        result_json = response.json()
        return self._converter_func(result_json)


def get_json_graph_client(host, api_key, retries=1):
    """Get a client that returns raw json"""
    return _KenshoGraphClient(host, api_key, lambda x: x, retries=retries)


def get_pandas_graph_client(host, api_key, retries=1):
    """Get a client that returns raw json"""
    return _KenshoGraphClient(
        host, api_key, _api_result_to_frame, retries=retries)

# %%
client = get_pandas_graph_client('https://www.kensho.com/external/v1', '75cabbcbb13902d342ab56354f2f24830b4ca92b')

print(client.list_timeline_types())
# Out:
# [{'timeline_type': 'Academia'}, {'timeline_type': 'Activism'}, {'timeline_type': 'Administrative'}, {'timeline_type': 'Advisory'}, {'timeline_type': 'All Time High'}, {'timeline_type': 'Analyst Meetings'}, {'timeline_type': 'Analyst/Investor Day'}, {'timeline_type': 'Announcement of Interim Management Statement'}, {'timeline_type': 'Annual General Meeting'}, {'timeline_type': 'Appointments'}, {'timeline_type': 'Arms Deals'}, {'timeline_type': 'Astronomical Events'}, {'timeline_type': 'Auditor Changes'}, {'timeline_type': 'Automobiles'}, {'timeline_type': 'Awards'}, {'timeline_type': 'Bankruptcy'}, {'timeline_type': 'Bilateral Relations'}, {'timeline_type': 'Business Activity'}, {'timeline_type': 'Business Operations'}, {'timeline_type': 'Buyback - Change in Plan Terms'}, {'timeline_type': 'Buyback Announcements by Company'}, {'timeline_type': 'Buyback Closings by Company'}, {'timeline_type': 'Buyback Tranche Update'}, {'timeline_type': 'Buyback Transaction Announcements'}, {'timeline_type': 'Buyback Transaction Cancellations'}, {'timeline_type': 'Buybacks'}, {'timeline_type': 'CEO Speeches'}, {'timeline_type': 'Capital Raises'}, {'timeline_type': 'Central Bank Communications'}, {'timeline_type': 'Central Bank Conferences'}, {'timeline_type': 'Central Bank Meetings'}, {'timeline_type': 'Central Bank Rate Decreases'}, {'timeline_type': 'Central Bank Rate Increases'}, {'timeline_type': 'Central Bank Rate Unchanged'}, {'timeline_type': 'Central Bank Speeches'}, {'timeline_type': 'Central Banks'}, {'timeline_type': 'Civil Conflicts'}, {'timeline_type': 'Civil Society'}, {'timeline_type': 'Climate'}, {'timeline_type': 'Communications'}, {'timeline_type': 'Company Conference Presentations'}, {'timeline_type': 'Confirmations'}, {'timeline_type': 'Conflicts'}, {'timeline_type': 'Considering Multiple Strategic Alternatives'}, {'timeline_type': 'Construction'}, {'timeline_type': 'Consumer'}, {'timeline_type': 'Consumer Credit'}, {'timeline_type': 'Consumer Income'}, {'timeline_type': 'Consumer Prices'}, {'timeline_type': 'Consumer Spending'}, {'timeline_type': 'Contracts'}, {'timeline_type': 'Corporate'}, {'timeline_type': 'Corporate Guidance - Lowered'}, {'timeline_type': 'Corporate Guidance - New/Confirmed'}, {'timeline_type': 'Corporate Guidance - Raised'}, {'timeline_type': 'Corporate Guidance - Unusual Events'}, {'timeline_type': 'Cultural'}, {'timeline_type': 'Curated'}, {'timeline_type': 'Cyberattacks'}, {'timeline_type': 'Cybersecurity'}, {'timeline_type': 'Debt Defaults'}, {'timeline_type': 'Delayed Earnings Announcements'}, {'timeline_type': 'Delayed SEC Filings'}, {'timeline_type': 'Departures'}, {'timeline_type': 'Dining'}, {'timeline_type': 'Diplomacy'}, {'timeline_type': 'Discontinued Operations & Downsizings'}, {'timeline_type': 'Discontinued Operations/Downsizings'}, {'timeline_type': 'Dividend Affirmations'}, {'timeline_type': 'Dividend Cancellation'}, {'timeline_type': 'Dividend Decreases'}, {'timeline_type': 'Dividend Increases'}, {'timeline_type': 'Dividend Initiation'}, {'timeline_type': 'Dividends'}, {'timeline_type': 'Earnings'}, {'timeline_type': 'Earnings releases'}, {'timeline_type': 'Earthquakes by Country'}, {'timeline_type': 'Econometric'}, {'timeline_type': 'Economic Data'}, {'timeline_type': 'Economic Outlook Reports'}, {'timeline_type': 'Elections'}, {'timeline_type': 'Employment'}, {'timeline_type': 'Energy'}, {'timeline_type': 'Enforcement'}, {'timeline_type': 'Entertainment'}, {'timeline_type': 'Environmental'}, {'timeline_type': 'Epidemics'}, {'timeline_type': 'Exchange Changes'}, {'timeline_type': 'Exchange Operations'}, {'timeline_type': 'Executive Orders'}, {'timeline_type': 'Expansions'}, {'timeline_type': 'Fashion'}, {'timeline_type': 'Film'}, {'timeline_type': 'Financial'}, {'timeline_type': 'Financial Crises'}, {'timeline_type': 'Financial Reporting'}, {'timeline_type': 'Fiscal Policy'}, {'timeline_type': 'Fixed Income Issuance Announcements by Company'}, {'timeline_type': 'Fixed Income Issuance ...
